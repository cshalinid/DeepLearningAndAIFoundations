# %% [markdown]
# # Advanced Programme in Deep Learning (Foundations and Applications)
# ## A Program by IISc and TalentSprint
# ### Implementation of Text-to-Speech (TTS) Model

# %% [markdown]
# ## Learning Objectives
#
# At the end of the experiment, you will be able to
#
# * understand Tacotron, Fastspeech, and Glowtts
# * use pretrained models to build Text-to-speech model and evaluate them
# * perform model training for Tacotron2

# %% [markdown]
# ### **Dataset Description**
#
# The LJSpeech dataset is a public domain speech dataset consisting of 13,100 short audio clips of a single speaker reading passages from 7 non-fiction books. A transcription is provided for each clip. Clips vary in length from 1 to 10 seconds and have a total length of approximately 24 hours.
#
# The texts were published between 1884 and 1964, and are in the public domain. The audio was recorded in 2016-17 by the LibriVox project and is also in the public domain.
#
# The datasets can be downloaded from the following [link](https://data.keithito.com/data/speech/LJSpeech-1.1.tar.bz2)

# %% [markdown]
# #### **About DataSet**
#
# 1. The audio clips range in length from approximately 1 second to 10 seconds. They were segmented automatically based on silences in the recording. Clip boundaries generally align with sentence or clause boundaries, but not always.
#
# 2. The text was matched to the audio manually, and a QA pass was done to ensure that the text accurately matched the words spoken in the audio.
#
# 3. The original LibriVox recordings were distributed as 128 kbps MP3 files. As a result, they may contain artifacts introduced by the MP3 encoding.
#
# #### **File Format**
#
# Metadata is provided in transcripts.csv. This file consists of one record per line, delimited by the pipe character (0x7c). The fields are:
#
# 1. **ID**: This is the name of the corresponding .wav file
# 2. **Transcription**: Words spoken by the reader (UTF-8)
# 3. **Normalized Transcription**: Transcription with numbers, ordinals, and monetary units expanded into full words (UTF-8).
#
# Each audio file is a single-channel 16-bit PCM WAV with a sample rate of 22050 Hz.

# %% [markdown]
# ### Importing required packages

# %%
# %tensorflow_version 1.x

def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn
import os, sys
from os.path import exists, join, basename, splitext

# Downloading the github repository

tacotron_git_repo_url = 'https://github.com/bloodraven66/tacotron2_train_batch.git'
fastspeech_git_repo_url = 'https://github.com/Talentsprint2011/FastSpeech.git'
glowtts_git_repo_url = 'https://github.com/bloodraven66/glowtts.git'
TTS_utils_repo_url = 'https://github.com/bloodraven66/ASR_TTS.git'

# Splitting the text to get the name of the model
tacotron_project_name = splitext(basename(tacotron_git_repo_url))[0]
fastspeech_project_name = splitext(basename(fastspeech_git_repo_url))[0]
glowtts_project_name = splitext(basename(glowtts_git_repo_url))[0]
TTS_utils_project_name = splitext(basename(TTS_utils_repo_url))[0]

if not exists(tacotron_project_name):
  # !git clone -q --recursive {tacotron_git_repo_url}
  # !cd {tacotron_project_name}/waveglow && git checkout 9168aea
  # !pip install -q librosa==0.9.1 unidecode easydict

if not exists(fastspeech_project_name):
    # !git clone -q --recursive {fastspeech_git_repo_url}

if not exists(glowtts_project_name):
    # !git clone -q --recursive {glowtts_git_repo_url}

if not exists(TTS_utils_project_name):
    # !git clone -q --recursive {TTS_utils_repo_url}

# !pip install git+https://github.com/bloodraven66/ASR_TTS.git
# !pip install -q wget
sys.path.append(join(tacotron_project_name, 'waveglow/'))
sys.path.append(tacotron_project_name)
sys.path.append(fastspeech_project_name)
sys.path.append(glowtts_project_name)
# Out:
# Previous HEAD position was 5bc2a53 README.md: reporting correct number after finding bug in inference time code
# HEAD is now at 9168aea README.md: layout
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.1/213.1 kB 3.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.5/235.5 kB 11.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 35.7 MB/s eta 0:00:00
# Collecting git+https://github.com/bloodraven66/ASR_TTS.git
#   Cloning https://github.com/bloodraven66/ASR_TTS.git to /tmp/pip-req-build-vb7njbn6
#   Running command git clone --filter=blob:none --quiet https://github.com/bloodraven66/ASR_TTS.git /tmp/pip-req-build-vb7njbn6
#   Resolved https://github.com/bloodraven66/ASR_TTS.git to commit b3c12bbe69c8ab512570b334baf8e1ac3f4d5cd2
#   Preparing metadata (setup.py) ... done
# Collecting ffmpeg-python (from ASR_TTS==0.0.3)
#   Downloading ffmpeg_python-0.2.0-py3-none-any.whl.metadata (1.7 kB)
# Collecting beautifultable (from ASR_TTS==0.0.3)
#   Downloading beautifultable-1.1.0-py2.py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: soundfile in /usr/local/lib/python3.10/dist-packages (from ASR_TTS==0.0.3) (0.12.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from beautifultable->ASR_TTS==0.0.3) (0.2.13)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from ffmpeg-python->ASR_TTS==0.0.3) (1.0.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from soundfile->ASR_TTS==0.0.3) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->soundfile->ASR_TTS==0.0.3) (2.22)
# Downloading beautifultable-1.1.0-py2.py3-none-any.whl (28 kB)
# Downloading ffmpeg_python-0.2.0-py3-none-any.whl (25 kB)
# Building wheels for collected packages: ASR_TTS
#   Building wheel for ASR_TTS (setup.py) ... done
#   Created wheel for ASR_TTS: filename=ASR_TTS-0.0.3-py3-none-any.whl size=8728 sha256=f5de5659b2bc39fe72adf9cf1e1dcae8e976dabb37df9182594f8ff6468cbf62
#   Stored in directory: /tmp/pip-ephem-wheel-cache-q7fk79dw/wheels/5c/d2/38/5d2e8898948d68fd5f4386898ec5f7f78f0093b5c19863ef36
# Successfully built ASR_TTS
# Installing collected packages: ffmpeg-python, beautifultable, ASR_TTS
# Successfully installed ASR_TTS-0.0.3 beautifultable-1.1.0 ffmpeg-python-0.2.0
#   Preparing metadata (setup.py) ... done
#   Building wheel for wget (setup.py) ... done

# %% [markdown]
# ### Downloading the pretrained models

# %%
# !wget -qq https://cdn.extras.talentsprint.com/DLFA/Experiment_related_data/tacotron2_statedict.pt

# %%
# !wget -qq https://cdn.extras.talentsprint.com/DLFA/Experiment_related_data/pretrained.pth
# !wget -qq https://cdn.extras.talentsprint.com/DLFA/Experiment_related_data/checkpoint_135000.pth

# %%
ls
# Out:
# ASR_TTS/               FastSpeech/  pretrained.pth  tacotron2_statedict.pt
# checkpoint_135000.pth  glowtts/     sample_data/    tacotron2_train_batch/

# %%
import json
import time
import torch
import random
import matplotlib
import numpy as np
import IPython.display as ipd
import matplotlib.pylab as plt
from scipy.io import wavfile
from IPython.display import clear_output
import ipywidgets as widgets
from tqdm import tqdm
from ASR_TTS import tts
from ASR_TTS.utils import plot_data, plot_data_3x, download_all_models
# Text processing toolkit
# !pip install unidecode
plt.rcParams["axes.grid"] = False
# Out:
# Requirement already satisfied: unidecode in /usr/local/lib/python3.10/dist-packages (1.3.8)

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Loading the pretrained models

# %%
waveglow_pretrained = 'waveglow_256channels_universal_v5.pt'
glowtts_pretrained = '/content/pretrained.pth'
tacotron2_pretrained = '/content/tacotron2_statedict.pt'
fastspeech_pretrained = '/content/checkpoint_135000.pth'

# %%
# Evaluate TTS model with different datasets
tts.list_datasets()
# Out:
# Training
# +----------+--------------+-----------+----------+-----------------------------+
# | dataset  | num speakers | num sente | duration |            link             |
# |          |              |   nces    |          |                             |
# +----------+--------------+-----------+----------+-----------------------------+
# | ljspeech |      1       |   13100   | 24 hours | https://keithito.com/LJ-Spe |
# |          |              |           |          |        ech-Dataset/         |
# +----------+--------------+-----------+----------+-----------------------------+
# Evaluation
# +------------+---------------+---------------------------------------+---------+
# |  dataset   | num sentences |                source                 | evaluat |
# |            |               |                                       | ion met |
# |            |               |                                       |  rics   |
# +------------+---------------+---------------------------------------+---------+
# | ljspeech_s |      500      | All sentences from LJSpeech test set  |   MOS   |
# |  entences  |               |        from tacotron2 training        |         |
# +------------+---------------+---------------------------------------+---------+
# | fastspeech |      42       | Sentences which are known to peform p |   MOS   |
# | _hard_sent |               | oorly in TTS, manually listed in Fast |         |
# |   ences    |               |             Speech paper              |         |
# +------------+---------------+---------------------------------------+---------+
# | common_voi |      50       | Sentences randomly selected from comm |   MOS   |
# | ce_sentenc |               |            on voice corpus            |         |
# |     es     |               |                                       |         |
# +------------+---------------+---------------------------------------+---------+
# MOS: Mean Opinion Score (subjective evaluation)

# %%
# Listing the model names, the pretrained model and links used
tts.list_models()
# Out:
# Text to Spectogram
# +------------+------------------------+---------------------------+------------+
# | model name |      publication       |           code            | pretrained |
# +------------+------------------------+---------------------------+------------+
# | tacotron2  | https://arxiv.org/pdf/ | https://github.com/NVIDIA |  LJSpeech  |
# |            |     1712.05884.pdf     |        /tacotron2         |            |
# +------------+------------------------+---------------------------+------------+
# | fastspeech | https://arxiv.org/pdf/ | https://github.com/xcmyz/ |  LJSpeech  |
# |            |     1905.09263.pdf     |        FastSpeech         |            |
# +------------+------------------------+---------------------------+------------+
# |  glow-tts  | https://arxiv.org/pdf/ | https://github.com/jaywal |  LJSpeech  |
# |            |     2005.11129.pdf     |      nut310/glow-tts      |            |
# +------------+------------------------+---------------------------+------------+
# Vocoder
# +------------+---------------------------+------------------------+------------+
# | model name |        publication        |          code          | pretrained |
# +------------+---------------------------+------------------------+------------+
# |  WaveGlow  | https://arxiv.org/pdf/181 | https://github.com/NVI |  LJSpeech  |
# |            |        1.00002.pdf        |      DIA/waveglow      |            |
# +------------+---------------------------+------------------------+------------+

# %% [markdown]
# ### **TACOTRON2**
#
# A text-to-speech synthesis system typically consists of multiple stages, such as a text analysis frontend, an acoustic model and an audio synthesis module. Building these components often requires extensive domain expertise and may contain brittle design choices. Here, we are using **Tacotron**, an end-to-end generative text-to-speech model that synthesizes speech directly from characters. Given `<text, audio>` pairs, the model can be trained completely from scratch with random initialization. Tacotron achieves a 3.82 subjective 5-scale mean opinion score on US English, outperforming a production parametric system in terms of naturalness.It does not require phoneme-level alignment, so it can easily scale to using large amounts of acoustic data with transcripts. In addition, since Tacotron generates speech at the frame level, it’s substantially faster than sample-level autoregressive methods.

# %% [markdown]
# #### Model Architecture
#
#
# <center>
# <img src="https://cdn.iisc.talentsprint.com/DLFA/Experiment_related_data/tacotron2%20architecture1.png" width=600px height=400px/>
# </center>
# <br><br>
#
# To know more about the architecture click [here](https://arxiv.org/pdf/1712.05884.pdf).

# %% [markdown]
# Let us import all the packages required to implement tacotron2

# %%
from hparams import create_hparams
from model import Tacotron2
import copy

from layers import TacotronSTFT
from audio_processing import griffin_lim
from text import text_to_sequence
from denoiser import Denoiser
from glow import WaveGlow
from convert_model import update_model

# %% [markdown]
# Now, we will initialize tacotron2 with the pretrained model. Here, we are defining the hyperparameter and loading the model according to the hyperparameters.

# %%
torch.set_grad_enabled(False)
hparams = create_hparams()
hparams.sampling_rate = 22050
tacotron_model = Tacotron2(hparams)
tacotron_model.load_state_dict(torch.load(tacotron2_pretrained)['state_dict'])
_ = tacotron_model.eval()

# %% [markdown]
# Synthesize a text or replace the TEXT with your text if you want try out another one.

# %%
TEXT = "Today's assignment is on text to speech"

# %% [markdown]
# Here, we will creates a tensor representation of the input text sequence `(example_text)` using `tacotron2.text_to_sequence()`.

# %%
sequence = np.array(text_to_sequence(TEXT, ['english_cleaners']))[None, :]
sequence = torch.autograd.Variable(torch.from_numpy(sequence)).long()
sequence = sequence

# %% [markdown]
# #### Mel Spectogram
#
# Before moving ahead, you should know about **Mel Spectogram**.
#
# Mel spectrogram is a spectrogram that is converted to a Mel scale. Then, what is the spectrogram and The Mel Scale? Let us have a look at it.
#
# **The Mel Scale**
#
# Studies have shown that humans do not perceive frequencies on a linear scale. We are better at detecting differences in lower frequencies than higher frequencies. For example, we can easily tell the difference between 500 and 1000 Hz, but we will hardly be able to tell a difference between 10,000 and 10,500 Hz, even though the distance between the two pairs are the same.
# In 1937, Stevens, Volkmann, and Newmann proposed a unit of pitch such that equal distances in pitch sounded equally distant to the listener. This is called the **mel scale**. We perform a mathematical operation on frequencies to convert them to the mel scale.
#
# <center>
# <img src="
# https://cdn.iisc.talentsprint.com/DLFA/Experiment_related_data/mel%20scale.gif" width=400px height=350px/>
# </center>
# <br><br>
#
# **The Mel Spectrogram**
#
# A mel spectrogram is a spectrogram where the frequencies are converted to the mel scale and the representation of a mel spectogram is given below.
#
# <center>
# <img src="https://cdn.iisc.talentsprint.com/DLFA/Experiment_related_data/mel%20spectogram.png" width=400px height=300px/>
# </center>
# <br><br>

# %% [markdown]
# Now, we will convert the text into mel spectrogram using tacotron2 and plot it. It is a commonly used feature representation which acts as the target in the speech synthesis.

# %%
def plot_data_3x(data, figsize=(16, 4)):
    fig, axes = plt.subplots(1, len(data), figsize=figsize)
    for i in range(len(data)):
        axes[i].imshow(data[i], aspect='auto', origin='lower',
                       interpolation='none', cmap='viridis')

# %%
mel_outputs, mel_outputs_postnet, _, alignments = tacotron_model.inference(sequence)
plot_data_3x((mel_outputs.data.cpu().numpy()[0],
           mel_outputs_postnet.data.cpu().numpy()[0],
           alignments.data.cpu().numpy()[0].T))

# %% [markdown]
# **First plot**: It is the final output of the tacotron2 model.
#
# **Second plot**: It is the output before the postnet layer (last layer in the model architecture).
#
# **Third plot**: It is the alignment matrix and it is representing how the input text represents and the output speech feature frames are aligned.
# Here, the `x-axis` is the speech part and `y-axis` is the text part.

# %%
import librosa
import numpy as np

# Compatibility fix for NumPy deprecations
np.float = float

MAX_WAV_VALUE = 32768.0
y_gen_tst = mel_outputs.detach().cpu().numpy()[0]
print(y_gen_tst.shape)
y_gen_tst = np.exp(y_gen_tst)

S = librosa.feature.inverse.mel_to_stft(
        y_gen_tst,
        power=1,
        sr=22050,
        n_fft=1024,
        fmin=0,
        fmax=8000.0)

audio = librosa.griffinlim(
        S,
        n_iter=32,
        hop_length=256,
        win_length=1024)

audio = audio * MAX_WAV_VALUE
audio = audio.astype('int16')
print(audio.shape)
# Out:
# (80, 214)
# (54528,)

# %% [markdown]
# ### **FastSpeech**
#
# A non-autoregressive text to speech (TTS) models such as **FastSpeech** can synthesize speech significantly faster than previous autoregressive models with comparable quality.
#
# Here, we will understand the architecture design of FastSpeech. To generate a target melspectrogram sequence in parallel, we design a novel feed-forward structure, instead of using the encoder-attention-decoder based architecture as adopted by most sequence to sequence based autoregressive [14, 22, 25] and non-autoregressive [7, 8, 26] generation. The overall model architecture of
# FastSpeech is shown in the below figure. Going further, We describe the components in detail.
#
# <center>
# <img src="https://cdn.iisc.talentsprint.com/DLFA/Experiment_related_data/fastspeech.png" width=600px height=300px/>
# </center>
# <br><br>
#
# The overall architecture for FastSpeech is as follows:
#
# 1. The feed-forward Transformer
#
# 2. The feed-forward Transformer block
#
# 3. The length regulator
#
# 4. The duration predictor.
#
# MSE loss denotes the loss between predicted and extracted duration, which only exists in the training process. NOw, let us discuss about these architecture elements.
#
# **1. Feed-Forward Transformer**
#
# The architecture for FastSpeech is a feed-forward structure based on self-attention in Transformer and 1D convolution . We call this structure as Feed-Forward Transformer (FFT), as shown in the figure 1(a). Feed-Forward Transformer stacks multiple **FFT blocks** for phoneme to mel-spectrogram transformation, with N blocks on the phoneme side, and N blocks on the mel-spectrogram side, with a length regulator in between to bridge the length gap between the phoneme and mel-spectrogram sequence. Each FFT block consists of a self-attention and 1D convolutional network, as shown in Figure 1(b). The self-attention network consists of a multi-head attention to extract the cross-position information. Different from the 2-layer dense network in
# Transformer, we use a 2-layer 1D convolutional network with ReLU activation. The motivation is that the adjacent hidden states are more closely related in the character/phoneme and mel-spectrogram sequence in speech tasks. We evaluate the effectiveness of the 1D convolutional network in the experimental section. Following Transformer, residual connections, layer normalization, and dropout are added after the self-attention network and 1D convolutional network respectively.
#
# **2. Length Regulator**
#
# The length regulator (Figure 1c) is used to solve the problem of length mismatch between the phoneme and spectrogram sequence in the Feed-Forward Transformer, as well as to control the voice speed. The length of a phoneme sequence is usually smaller than that of its mel-spectrogram sequence, and each phoneme corresponds to several mel-spectrograms. We refer to the length of the mel-spectrograms that corresponds to a phoneme as the phoneme duration
#
# **3. Duration Predictor**
#
# Phoneme duration prediction is important for the length regulator. As shown in Figure 1d, the duration predictor consists of a 2-layer 1D convolutional network with ReLU activation, each followed by the layer normalization and the dropout layer, and an extra linear layer to output a scalar, which
# is exactly the predicted phoneme duration. Note that this module is stacked on top of the FFT blocks on the phoneme side and is jointly trained with the FastSpeech model to predict the length of 4 mel-spectrograms for each phoneme with the mean square error (MSE) loss. We predict the length in
# the logarithmic domain, which makes them more Gaussian and easier to train. Note that the trained duration predictor is only used in the TTS inference phase, because we can directly use the phoneme duration extracted from an autoregressive teacher model in training.

# %% [markdown]
# Importing the required packages for implementation FastSpeech.

# %%
from FastSpeech.fs_eval import get_DNN
from FastSpeech import fs_hparams as hp
from FastSpeech import text

# %%
# Loading the FastSpeech model
fastspeech_model = get_DNN(fastspeech_pretrained)

# %% [markdown]
# Synthesize a text or replace the TEXT with your text if you want try out another one.

# %%
TEXT = ["Today's assignment is on text to speech"]

# %%
# Creating a tensor representation of the input text sequence
TEXT = [text.text_to_sequence(t, hp.text_cleaners) for t in TEXT]
text_ = np.array(TEXT[0])
text_ = np.stack([text_])

# Extracting the number of the character in the text sequence
src_pos = np.array([i+1 for i in range(text_.shape[1])])
src_pos = np.stack([src_pos])

# Converting numpy array into torch tensor and loading it to GPU
sequence = torch.from_numpy(text_).cuda().long()
src_pos = torch.from_numpy(src_pos).cuda().long()

# %%
def plot_data(data, figsize=(5, 4)):
    plt.figure(figsize=figsize)
    plt.imshow(data, aspect='auto', origin='lower',
                    interpolation='none', cmap='viridis')

# %%
# Predicting the mel sepctogram from tensor representation of text
with torch.no_grad():
    _, mel = fastspeech_model.module.forward(sequence, src_pos, alpha=1)
mel = mel.contiguous().transpose(1, 2).squeeze().cpu().numpy()
plot_data(mel)

# %%
# Convert the generated mel spectrogram into an audio
import librosa
MAX_WAV_VALUE = 32768.0
y_gen_tst = mel
print(y_gen_tst.shape)
y_gen_tst = np.exp(y_gen_tst)
S = librosa.feature.inverse.mel_to_stft(
        y_gen_tst,
        power=1,
        sr=22050,
        n_fft=1024,
        fmin=0,
        fmax=8000.0)
audio = librosa.core.griffinlim(
        S,
        n_iter=32,
        hop_length=256,
        win_length=1024)
audio = audio * MAX_WAV_VALUE
audio = audio.astype('int16')
print(audio.shape)
ipd.Audio(audio, rate=22050)
# Out:
# (80, 259)
# (66048,)
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### **Glow-TTS: A Generative Flow for Text-to-Speech**
#
# Let us first understand why there is a necessity of another model which is Glow-TTS.
#
# **Performance of other models**
#
# Text-to-Speech (TTS) is the task to generate speech from text, and deep-learning-based TTS models have succeeded in producing natural speech indistinguishable from human speech. Among neural TTS models, autoregressive models such as Tacotron 2 show the state-of-the-art performance. Based on these autoregressive models, there have been many advances in generating diverse speech in terms of modelling different speaking styles or various prosodies.
#
# **Problem with Autoregressive TTS models**
#
# espite the high quality of autoregressive TTS models, there are a few difficulties in deploying end-to-end autoregressive models directly in real-time services. As the synthesizing time of the models grows linearly with the output length, undesirable delay caused by generating long speech can be propagated to the multiple pipelines of TTS systems without designing sophisticated frameworks. In addition, most of the autoregressive models show lack of robustness in some cases. For example, when the input text includes the repeated words, autoregressive TTS models often produce serious attention errors.
#
# To overcome such limitations of the autoregressive TTS models, parallel TTS models such as **FastSpeech** have been proposed. These models can synthesize mel-spectrogram significantly faster than the autoregressive TTS models. In addition to the fast sampling, FastSpeech reduces the failure cases for the extremely hard sentences by enforcing its alignment monotonic.
#
# **Problem with FastSpeech**
#
# However, these strengths of parallel TTS models come from the well-aligned attention map between text and speech, which is extracted from their external aligner. Recently proposed parallel models address these challenges by extracting attention maps from the pre-trained autoregressive models. Therefore, the performance of the parallel TTS models critically depends on that of the autoregressive TTS models. Furthermore, since the parallel TTS models assume this alignment to be given during training, they cannot be trained without the external aligners.
#
# Here, our goal is to eliminate the necessity of any external aligner from the training procedure of parallel TTS models. Therefore, **Glow-TTS** comes into consideration.
#
# **What is Glow-TTS?**
#
# Glow-TTS is a flow-based generative model for parallel TTS that can internally learn its own alignment. Glow-TTS is directly trained to maximize the log-likelihood of speech given text, and its sampling process is totally parallel due to the properties of the generative flow. In order to eliminate any dependency on other networks, we introduce Monotonic Alignment Search (MAS), a novel method to search for the most probable monotonic alignment with only text and latent representation of speech. This internal alignment search algorithm simplifies the entire training procedure of our parallel TTS models so that it requires only 3 days for training on two GPUs.
#
# Without any external aligner, our parallel TTS model can generate mel-spectrograms 15.7 times faster than the autoregressive TTS model, Tacotron 2, while maintaining the comparable performance. Glow-TTS also provides diverse speech synthesis, in contrast to other TTS models, which have their stochasticities only in dropout operations. We can control some properties of synthesized samples from Glow-TTS by altering the latent variable of normalizing flows.

# %% [markdown]
# #### Loading all the prerequisites for Glow-TTS

# %%
# %cd /content/
from text import text_to_sequence, cmudict
from text.symbols import symbols
from glowtts import models, utils, commons
from glowtts.text import text_to_sequence
# Copying the configuration files to be used by the pretrained models
# !cp glowtts/configs/base.json glowtts/configs/config.json
# Out:
# /content

# %%
# Loading the hyperparameter
hps = utils.get_hparams_from_dir('glowtts/configs/')

# Normalizing the output audio
def normalize_audio(x, max_wav_value=hps.data.max_wav_value):
    return np.clip((x / np.abs(x).max()) * max_wav_value, -32768, 32767).astype("int16")

# Defining the Glow-TTS model
glowtts_model = models.FlowGenerator(
    len(symbols) + getattr(hps.data, "add_blank", False),
    out_channels=hps.data.n_mel_channels,
    **hps.model).to("cuda")

# Loading a pretrained Glow-TTS model
utils.load_checkpoint(glowtts_pretrained, glowtts_model)
glowtts_model.decoder.store_inverse()
_ = glowtts_model.eval()

# %% [markdown]
# Synthesize a text or replace the TEXT with your text if you want try out another one.

# %%
tst_stn = "Today's assignment is on text to speech"

# %% [markdown]
# Preprocssing steps for input text.

# %%
cmu_dict = cmudict.CMUDict('glowtts/data/cmu_dictionary')
if getattr(hps.data, "add_blank", False):
    text_norm = text_to_sequence(tst_stn.strip(), ['english_cleaners'], cmu_dict)
    text_norm = commons.intersperse(text_norm, len(symbols))
else:
    tst_stn = " " + tst_stn.strip() + " "
    text_norm = text_to_sequence(tst_stn.strip(), ['english_cleaners'], cmu_dict)

# %% [markdown]
# Tensor representation of the text.

# %%
sequence = np.array(text_norm)[None, :]
x_tst = torch.autograd.Variable(torch.from_numpy(sequence)).cuda().long()
x_tst_lengths = torch.tensor([x_tst.shape[1]]).cuda()

# %% [markdown]
# Predicting the mel sepctogram from tensor representation of text.

# %%
with torch.no_grad():
  noise_scale = .667
  length_scale = 1.0
  (y_gen_tst, *_), *_, (attn_gen, *_) = glowtts_model(x_tst, x_tst_lengths, gen=True, noise_scale=noise_scale, length_scale=length_scale)
print(y_gen_tst.shape)
plot_data(y_gen_tst.squeeze().cpu().numpy())
plot_data(attn_gen.squeeze().cpu().numpy())
# Out:
# torch.Size([1, 80, 238])

# %%
# Convert the generated mel spectrogram into an audio
import librosa
MAX_WAV_VALUE = 32768.0
y_gen_tst = y_gen_tst.detach().cpu().numpy()[0]

y_gen_tst = np.exp(y_gen_tst)
S = librosa.feature.inverse.mel_to_stft(
        y_gen_tst,
        power=1,
        sr=22050,
        n_fft=1024,
        fmin=0,
        fmax=8000.0)
audio = librosa.core.griffinlim(
        S,
        n_iter=32,
        hop_length=256,
        win_length=1024)
audio = audio * MAX_WAV_VALUE
audio = audio.astype('int16')
print(audio.shape)
ipd.Audio(audio, rate=22050)
# Out:
# (60672,)
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Defining a function `batch_process` which takes the input as the `model name` and the `TEXT`.

# %%
# Preprocessing the input text for any given model
def batch_process(modelname, TEXT, device='cuda'): # device = 'cuda' or 'cpu'
    text_sequences = []
    text_positions = []
    if modelname == 'tacotron2':
        for TEXT_ in TEXT:
            sequence = np.array(text_to_sequence(TEXT_, ['english_cleaners']))[None, :]
            sequence = torch.autograd.Variable(torch.from_numpy(sequence)).long()
            text_sequences.append(sequence.to(device))

    elif modelname == 'fastspeech':
        for TEXT_ in TEXT:
            TEXT_ = np.stack([np.array(text.text_to_sequence(TEXT_, hp.text_cleaners))])
            src_pos = np.stack([np.array([i+1 for i in range(TEXT_.shape[1])])])
            text_positions.append(torch.from_numpy(src_pos).cuda().long())
            text_sequences.append(torch.from_numpy(TEXT_).cuda().long())

    elif modelname == 'glowtts':
        cmu_dict = cmudict.CMUDict('glowtts/data/cmu_dictionary')
        for TEXT_ in TEXT:
            if getattr(hps.data, "add_blank", False):
                text_norm = text_to_sequence(TEXT_.strip(), ['english_cleaners'], cmu_dict)
                text_norm = commons.intersperse(text_norm, len(symbols))
            else:
                TEXT_ = " " + TEXT_.strip() + " "
                text_norm = text_to_sequence(TEXT_.strip(), ['english_cleaners'], cmu_dict)
            sequence = np.array(text_norm)[None, :]
            text_sequences.append(torch.autograd.Variable(torch.from_numpy(sequence)).to(device).long())
            text_positions.append(torch.tensor([x_tst.shape[1]]).to(device))
    else:
        raise NotImplementedError
    return text_sequences, text_positions

# %% [markdown]
# Making predictions for the model using the input text.

# %%
# Predictions from the preprocessed text into mel spectograms and waveforms
def predict(modelname, input_text, positions):
    predicted = []
    wav = []
    num_samples = len(input_text)
    for i in tqdm(range(num_samples)):
        if modelname == 'tacotron2':
            predited_, _, _, _ = tacotron_model.inference(input_text[i])
            predicted.append(predited_)
        elif modelname == 'fastspeech':
            with torch.no_grad():
                _, predicted_ = fastspeech_model.module.forward(input_text[i], positions[i], alpha=1)
                predicted.append(predicted_.contiguous().transpose(1, 2))
        elif modelname == 'glowtts':
            (predicted_, *_), *_, (_, *_) = glowtts_model(input_text[i], positions[i], gen=True, noise_scale=0.667, length_scale=1.0)
            predicted.append(predicted_)
        else:
            raise NotImplementedError

        # wav.append(waveglow.infer(predicted[-1], sigma=.666).cpu().numpy())
        # print(predicted[-1].shape)

        # Convert the generated mel spectrogram into an audio
        import librosa
        MAX_WAV_VALUE = 32768.0
        y_gen_tst = predicted[-1].detach().cpu().numpy()[0]
        print(y_gen_tst.shape)
        y_gen_tst = np.exp(y_gen_tst)
        S = librosa.feature.inverse.mel_to_stft(
                y_gen_tst,
                power=1,
                sr=22050,
                n_fft=1024,
                fmin=0,
                fmax=8000.0)
        audio = librosa.core.griffinlim(
                S,
                n_iter=32,
                hop_length=256,
                win_length=1024)
        audio = audio * MAX_WAV_VALUE
        audio = audio.astype('int16')
        wav.append(audio)
    return predicted, wav

# %% [markdown]
# #### Downloading the LJSpeech Dataset

# %%
import tarfile
import wget
if not os.path.exists('LJSpeech-1.1/'):
    url = "https://cdn.iisc.talentsprint.com/DLFA/Experiment_related_data/LJSpeech-1.1.tar.bz2"
    wget.download(url)
    tar = tarfile.open("LJSpeech-1.1.tar.bz2", "r:bz2")
    tar.extractall()
    tar.close()

ljspeech_path = 'LJSpeech-1.1/wavs/'

test_paths = {'common_voice_sentences':'ASR_TTS/ASR_TTS/common_voice_sentences_for_TTS.txt',
              'fastspeech_hard_sentences':'ASR_TTS/ASR_TTS/tts_hard_sentences_fs.txt',
              'ljspeech_sentences':'tacotron2/filelists/ljs_audio_text_test_filelist.txt'}

test_dataset = 'fastspeech_hard_sentences'
modelname = 'fastspeech'

# %%
# Creating a dictionary of input text as well as the audios
test_dict = tts.extract_test_pairs(test_dataset, test_paths, ljspeech_path)

# %%
# Calling the batch process function to get text_sequences, text positions
text_sequences, text_positions = batch_process(modelname=modelname, TEXT=test_dict.values())
# Calling the predict function to get predicted_mel and wavs
predicted_mel, wavs = predict(modelname=modelname, input_text=text_sequences, positions=text_positions)
# Out:
#   0%|          | 0/42 [00:00<?, ?it/s]
# (80, 838)
#   2%|▏         | 1/42 [00:03<02:41,  3.94s/it]
# (80, 1010)
#   5%|▍         | 2/42 [00:06<02:14,  3.37s/it]
# (80, 990)
#   7%|▋         | 3/42 [00:09<02:06,  3.23s/it]
# (80, 900)
#  10%|▉         | 4/42 [00:12<01:55,  3.03s/it]
# (80, 814)
#  12%|█▏        | 5/42 [00:16<02:02,  3.31s/it]
# (80, 769)
#  14%|█▍        | 6/42 [00:18<01:44,  2.89s/it]
# (80, 897)
#  17%|█▋        | 7/42 [00:21<01:40,  2.88s/it]
# (80, 879)
#  19%|█▉        | 8/42 [00:24<01:35,  2.81s/it]
# (80, 792)
#  21%|██▏       | 9/42 [00:26<01:28,  2.68s/it]
# (80, 655)
#  24%|██▍       | 10/42 [00:29<01:30,  2.82s/it]
# (80, 919)
#  26%|██▌       | 11/42 [00:32<01:26,  2.79s/it]
# (80, 1049)
#  29%|██▊       | 12/42 [00:35<01:26,  2.88s/it]
# (80, 979)
#  31%|███       | 13/42 [00:38<01:25,  2.93s/it]
# (80, 635)
#  33%|███▎      | 14/42 [00:41<01:18,  2.81s/it]
# (80, 303)
#  36%|███▌      | 15/42 [00:42<01:04,  2.39s/it]
# (80, 366)
#  38%|███▊      | 16/42 [00:43<00:54,  2.08s/it]
# (80, 423)
#  40%|████      | 17/42 [00:45<00:46,  1.84s/it]
# (80, 895)
#  43%|████▎     | 18/42 [00:47<00:50,  2.10s/it]
# (80, 950)
#  45%|████▌     | 19/42 [00:50<00:53,  2.31s/it]
# (80, 1164)
#  48%|████▊     | 20/42 [00:55<01:06,  3.01s/it]
# (80, 1257)
#  50%|█████     | 21/42 [00:59<01:09,  3.30s/it]
# (80, 829)
#  52%|█████▏    | 22/42 [01:01<01:00,  3.05s/it]
# (80, 740)
#  55%|█████▍    | 23/42 [01:03<00:52,  2.74s/it]
# (80, 734)
#  57%|█████▋    | 24/42 [01:06<00:50,  2.79s/it]
# (80, 599)
#  60%|█████▉    | 25/42 [01:08<00:44,  2.61s/it]
# (80, 745)
#  62%|██████▏   | 26/42 [01:10<00:39,  2.49s/it]
# (80, 752)
#  64%|██████▍   | 27/42 [01:13<00:36,  2.41s/it]
# (80, 580)
#  67%|██████▋   | 28/42 [01:15<00:31,  2.24s/it]
# (80, 738)
#  69%|██████▉   | 29/42 [01:17<00:28,  2.17s/it]
# (80, 638)
#  71%|███████▏  | 30/42 [01:20<00:29,  2.42s/it]
# (80, 767)
#  74%|███████▍  | 31/42 [01:22<00:27,  2.47s/it]
# (80, 823)
#  76%|███████▌  | 32/42 [01:24<00:23,  2.39s/it]
# (80, 425)
#  79%|███████▊  | 33/42 [01:26<00:19,  2.12s/it]
# (80, 752)
#  81%|████████  | 34/42 [01:28<00:17,  2.16s/it]
# (80, 804)
#  83%|████████▎ | 35/42 [01:31<00:16,  2.36s/it]
# (80, 754)
#  86%|████████▌ | 36/42 [01:33<00:14,  2.42s/it]
# (80, 527)
#  88%|████████▊ | 37/42 [01:35<00:11,  2.22s/it]
# (80, 501)
#  90%|█████████ | 38/42 [01:37<00:07,  2.00s/it]
# (80, 632)
#  93%|█████████▎| 39/42 [01:39<00:05,  2.00s/it]
# (80, 1180)
#  95%|█████████▌| 40/42 [01:42<00:04,  2.46s/it]
# (80, 1303)
#  98%|█████████▊| 41/42 [01:47<00:03,  3.28s/it]
# (80, 805)
# 100%|██████████| 42/42 [01:50<00:00,  2.63s/it]

# %%
# Here we can listen the generated audio and the index represents which text file to play
index = 35
test_ = list(test_dict.values())[index]
print(test_)
ipd.Audio(wavs[index], rate=22050)
# Out:
# So we are back to Extended MAPI and C++ because . Extended MAPI does not have a dual interface VB or VB .Net can read .
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# **MOS Score**
#
#  **MOS, or, Mean Opinion Score**, is a measure of voice quality and is a quality measure that has been used in telephony for decades as a way to assess human users’ opinion of call quality. The test is used widely in VoIP networks to ensure quality voice transmission, test for quality issues, and provides a metric by which to measure voice degradation and performance.
#
# The most commonly used rating scale is the Absolute Category Ranking (ACR) scale, which ranges from 1 to 5. The levels of the Absolute Category Ranking are:
#
# 5 - Excellent
#
# 4 - Good
#
# 3 - Fair
#
# 2 - Poor
#
# 1 - Bad

# %%
# Preparing the test set predictions for MOS evaluation
# Here, the num_samples is the number of files to be considered for evaluation

args = tts.Args(test_dataset, modelname,num_samples=40)

audio_for_mos, text_for_mos = args.prepare_mos_files(wavs, list(test_dict.values()), ljspeech_path)
mos_scoring = tts.mos_scoring
def clicked(arg):
    if args.i > len(audio_for_mos)-1:
        clear_output()
        print(f'Evaluation done on {args.num_samples} samples!')
        args.score.append(mos_scoring.value)
        args.final_scores()
    else:
        args.score.append(mos_scoring.value)
        clear_output()
        print(text_for_mos[args.i])
        display_audio = ipd.Audio(audio_for_mos[args.i], rate=22050)
        display(display_audio)
        display(mos_scoring)
        args.i += 1
        display(next_button)

# Both the generated audio as well as actual audio from LJSpeech are mixed together. Once the MOS score have been provided
# for all the files the average MOS score for the generated as well as actual audio will be displayed

next_button = widgets.Button(description = 'Next')
next_button.on_click(clicked)
display(next_button)
# Out:
# Starting MOS evaluation on fastspeech model with 20 sentences from fastspeech_hard_sentences
# Button(description='Next', style=ButtonStyle())

# %% [markdown]
# ### Training the TTS Model : Tacotron2

# %% [markdown]
# Previously, we just evaluated different pretrained models based on the predictions (audio). Now, we have 78 text audio pairs that we will consider for training the model.

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
# %cd /content/tacotron2_train_batch
# Out:
# /content/tacotron2_train_batch

# %% [markdown]
# Here, the 78 audio text pairs are trained. At the end of each epoch the generated mel spectogram as well as their alignment matrix for one sample is stored.
#
# Keep traing  the model for atleast 1 or 2 hrs and look into the results periodically to undertand the imporovement.
#
# '''
# mel spec folder: /content/tacotron2_train_batch/predicted_mel
#
# alignment folder: /content/tacotron2_train_batch/alignment_plots
# '''

# %%
# !python3 train.py --output_directory=outdir --log_directory=logdir
# Out:
# 2024-11-18 05:30:47.465189: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-18 05:30:47.724921: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-18 05:30:47.789042: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-18 05:30:48.190861: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-18 05:30:49.889213: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# FP16 Run: False
# Dynamic Loss Scaling: True
# Distributed Run: False
# cuDNN Enabled: True
# cuDNN Benchmark: False
# /content/tacotron2_train_batch/stft.py:67: FutureWarning: Pass size=1024 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   fft_window = pad_center(fft_window, filter_length)
# /content/tacotron2_train_batch/layers.py:50: FutureWarning: Pass sr=22050, n_fft=1024, n_mels=80, fmin=0.0, fmax=8000.0 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel_basis = librosa_mel_fn(
# Epoch: 0
# /content/tacotron2_train_batch/utils.py:8: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:78.)
#   ids = torch.arange(0, max_len, out=torch.cuda.LongTensor(max_len))
# Train loss 0 47.253822
# Validation loss 0: 31.930643
# Train loss 1 33.465164
# Validation loss 1: 14.935398
# Epoch: 1
# Train loss 2 16.851900
# Validation loss 2: 12.149740
# Train loss 3 9.057828
# Validation loss 3: 13.519505
# Epoch: 2
# Train loss 4 6.345982
# Validation loss 4: 12.766163
# Train loss 5 5.997510
# Validation loss 5: 10.956791
# Epoch: 3
# Train loss 6 6.096971
# Validation loss 6:  9.232246
# Train loss 7 5.640892
# Validation loss 7:  8.031696
# Epoch: 4
# Train loss 8 5.674553
# Validation loss 8:  7.365185
# Train loss 9 5.400664
# Validation loss 9:  7.043733
# Epoch: 5
# Train loss 10 5.357203
# Validation loss 10:  6.977262
# Train loss 11 5.101483
# Validation loss 11:  6.441162
# Epoch: 6
# Train loss 12 5.192786
# Validation loss 12: 11.540860
# Train loss 13 5.045056
# Validation loss 13: 11.079267
# Epoch: 7
# Train loss 14 5.178705
# Validation loss 14: 10.714319
# Train loss 15 5.299320
# Validation loss 15: 10.284356
# Epoch: 8
# Train loss 16 5.868221
# Validation loss 16:  9.692693
# Train loss 17 5.975012
# Validation loss 17:  9.178786
# Epoch: 9
# Train loss 18 5.532432
# Validation loss 18:  8.538379
# Train loss 19 5.010407
# Validation loss 19:  7.990463
# Epoch: 10
# Train loss 20 4.988598
# Validation loss 20:  7.540000
# Train loss 21 4.569325
# Validation loss 21:  7.211994
# Epoch: 11
# Train loss 22 4.612435
# Validation loss 22:  7.337128
# Train loss 23 4.389611
# Validation loss 23:  7.445441
# Epoch: 12
# Train loss 24 4.582585
# Validation loss 24:  7.259830
# Train loss 25 4.439217
# Validation loss 25:  6.814955
# Epoch: 13
# Train loss 26 4.525826
# Validation loss 26:  6.676247
# Train loss 27 4.304942
# Validation loss 27:  6.809832
# Epoch: 14
# Train loss 28 4.477574
# Validation loss 28:  6.394223
# Train loss 29 4.219652
# Validation loss 29:  5.817442
# Epoch: 15
# Train loss 30 4.397692
# Validation loss 30:  5.782096
# Train loss 31 4.210922
# Validation loss 31:  6.312812
# Epoch: 16
# Train loss 32 4.388922
# Validation loss 32:  6.096791
# Train loss 33 4.272129
# Validation loss 33:  4.742610
# Epoch: 17
# Train loss 34 4.218096
# Validation loss 34:  5.252709
# Train loss 35 4.180520
# Validation loss 35:  5.791179
# Epoch: 18
# Train loss 36 4.168442
# Validation loss 36:  5.309926
# Train loss 37 3.947032
# Validation loss 37:  5.410178
# Epoch: 19
# Train loss 38 4.097488
# Validation loss 38:  5.737611
# Train loss 39 3.834261
# Validation loss 39:  6.382370
# Epoch: 20
# Train loss 40 3.976739
# Validation loss 40:  6.190904
# Train loss 41 3.789483
# Validation loss 41:  5.450573
# Epoch: 21
# Train loss 42 3.901586
# Validation loss 42:  5.309904
# Train loss 43 3.884747
# Validation loss 43:  5.440760
# Epoch: 22
# Train loss 44 3.787642
# Validation loss 44:  6.183243
# Train loss 45 3.717110
# Validation loss 45:  6.193391
# Epoch: 23
# Train loss 46 3.732580
# Validation loss 46:  5.551202
# Train loss 47 3.535164
# Validation loss 47:  5.432700
# Epoch: 24
# Train loss 48 3.669878
# Validation loss 48:  5.706790
# Train loss 49 3.469381
# Validation loss 49:  6.404904
# Epoch: 25
# Train loss 50 3.592334
# Validation loss 50:  6.118286
# Train loss 51 3.388530
# Validation loss 51:  5.483425
# Epoch: 26
# Train loss 52 3.547956
# Validation loss 52:  5.476250
# Train loss 53 3.406089
# Validation loss 53:  6.046770
# Epoch: 27
# Train loss 54 3.395926
# Validation loss 54:  6.330914
# Train loss 55 3.301400
# Validation loss 55:  5.756644
# Epoch: 28
# Train loss 56 3.273350
# Validation loss 56:  5.748878
# Train loss 57 3.196324
# Validation loss 57:  5.989277
# Epoch: 29
# Train loss 58 3.233845
# Validation loss 58:  5.789359
# Train loss 59 3.156311
# Validation loss 59:  5.724367
# Epoch: 30
# Train loss 60 3.172603
# Validation loss 60:  6.154342
# Train loss 61 3.166350
# Validation loss 61:  5.877042
# Epoch: 31
# Train loss 62 3.189474
# Validation loss 62:  5.485790
# Train loss 63 3.084894
# Validation loss 63:  5.914653
# Epoch: 32
# Train loss 64 3.090109
# Validation loss 64:  6.057381
# Train loss 65 3.055989
# Validation loss 65:  5.528196
# Epoch: 33
# Train loss 66 3.066641
# Validation loss 66:  5.666331
# Train loss 67 2.995283
# Validation loss 67:  5.956659
# Epoch: 34
# Train loss 68 2.991069
# Validation loss 68:  5.551304
# Train loss 69 2.914798
# Validation loss 69:  5.916295
# Epoch: 35
# Train loss 70 2.923235
# Validation loss 70:  5.323975
# Train loss 71 3.062128
# Validation loss 71:  5.286769
# Epoch: 36
# Train loss 72 2.947267
# Validation loss 72:  6.465290
# Train loss 73 3.000159
# Validation loss 73:  6.255638
# Epoch: 37
# Train loss 74 2.937322
# Validation loss 74:  5.179878
# Train loss 75 2.927626
# Validation loss 75:  5.247125
# Epoch: 38
# Train loss 76 2.920082
# Validation loss 76:  6.388312
# Train loss 77 2.893418
# Validation loss 77:  6.492300
# Epoch: 39
# Train loss 78 2.907137
# Validation loss 78:  5.459203
# Train loss 79 2.812447
# Validation loss 79:  5.465367
# Epoch: 40
# Train loss 80 2.810700
# Validation loss 80:  6.345575
# Train loss 81 2.935045
# Validation loss 81:  6.101577
# Epoch: 41
# Train loss 82 2.849181
# Validation loss 82:  5.016435
# Train loss 83 2.832631
# Validation loss 83:  4.948794
# Epoch: 42
# Train loss 84 2.831620
# Validation loss 84:  5.782423
# Train loss 85 2.784987
# Validation loss 85:  5.784268
# Epoch: 43
# Train loss 86 2.782590
# Validation loss 86:  5.055829
# Train loss 87 2.782991
# Validation loss 87:  5.088046
# Epoch: 44
# Train loss 88 2.798962
# Validation loss 88:  5.831076
# Train loss 89 2.741112
# Validation loss 89:  5.740129
# Epoch: 45
# Train loss 90 2.757598
# Validation loss 90:  4.854342
# Train loss 91 2.715501
# Validation loss 91:  4.843441
# Epoch: 46
# Train loss 92 2.686713
# Validation loss 92:  5.664251
# Train loss 93 2.805755
# Validation loss 93:  5.447968
# Epoch: 47
# Train loss 94 2.784073
# Validation loss 94:  4.493680
# Train loss 95 2.692953
# Validation loss 95:  4.207200
# Epoch: 48
# Train loss 96 2.695349
# Validation loss 96:  4.730851
# Train loss 97 2.585763
# Validation loss 97:  4.848287
# Epoch: 49
# Train loss 98 2.597823
# Validation loss 98:  4.189989
# Train loss 99 2.498682
# Validation loss 99:  4.217354
# Epoch: 50
# Train loss 100 2.495831
# Validation loss 100:  4.239929
# Train loss 101 2.475810
# Validation loss 101:  3.561749
# Epoch: 51
# Train loss 102 2.420831
# Validation loss 102:  3.109037
# Train loss 103 2.362261
# Validation loss 103:  3.642082
# Epoch: 52
# Train loss 104 2.312369
# Validation loss 104:  3.340904
# Train loss 105 2.376349
# Validation loss 105:  3.212574
# Epoch: 53
# Train loss 106 2.221553
# Validation loss 106:  3.737378
# Train loss 107 2.386357
# Validation loss 107:  3.630818
# Epoch: 54
# Train loss 108 2.506008
# Validation loss 108:  3.223660
# Train loss 109 2.174350
# Validation loss 109:  3.952498
# Epoch: 55
# Train loss 110 2.346874
# Validation loss 110:  4.371364
# Train loss 111 2.546721
# Validation loss 111:  3.989604
# Epoch: 56
# Train loss 112 2.295368
# Validation loss 112:  4.302803
# Train loss 113 2.212894
# Validation loss 113:  4.709730
# Epoch: 57
# Train loss 114 2.319142
# Validation loss 114:  4.691038
# Train loss 115 2.146912
# Validation loss 115:  4.017371
# Epoch: 58
# Train loss 116 2.178956
# Validation loss 116:  4.084724
# Train loss 117 2.222341
# Validation loss 117:  4.165190
# Epoch: 59
# Train loss 118 2.115498
# Validation loss 118:  4.208004
# Train loss 119 2.055621
# Validation loss 119:  3.865068
# Epoch: 60
# Train loss 120 2.179962
# Validation loss 120:  3.842986
# Train loss 121 2.069018
# Validation loss 121:  4.153897
# Epoch: 61
# Train loss 122 2.096360
# Validation loss 122:  3.731410
# Train loss 123 2.150741
# Validation loss 123:  3.313303
# Epoch: 62
# Train loss 124 2.063207
# Validation loss 124:  3.503964
# Train loss 125 1.975569
# Validation loss 125:  3.242872
# Epoch: 63
# Train loss 126 2.073879
# Validation loss 126:  3.288714
# Train loss 127 1.939106
# Validation loss 127:  3.287759
# Epoch: 64
# Train loss 128 2.001675
# Validation loss 128:  3.020986
# Train loss 129 1.984149
# Validation loss 129:  3.116824
# Epoch: 65
# Train loss 130 1.979320
# Validation loss 130:  2.961310
# Train loss 131 1.919856
# Validation loss 131:  2.424279
# Epoch: 66
# Train loss 132 2.004390
# Validation loss 132:  2.533467
# Train loss 133 1.979680
# Validation loss 133:  2.940308
# Epoch: 67
# Train loss 134 2.022145
# Validation loss 134:  2.774390
# Train loss 135 1.932176
# Validation loss 135:  2.286970
# Epoch: 68
# Train loss 136 2.060623
# Validation loss 136:  2.269920
# Train loss 137 1.966413
# Validation loss 137:  2.849896
# Epoch: 69
# Train loss 138 1.937634
# Validation loss 138:  2.787193
# Train loss 139 1.920595
# Validation loss 139:  2.236692
# Epoch: 70
# Train loss 140 1.960312
# Validation loss 140:  2.302040
# Train loss 141 1.911546
# Validation loss 141:  2.841363
# Epoch: 71
# Train loss 142 1.943621
# Validation loss 142:  2.766571
# Train loss 143 1.914495
# Validation loss 143:  2.210401
# Epoch: 72
# Train loss 144 1.925707
# Validation loss 144:  2.179849
# Train loss 145 1.877054
# Validation loss 145:  2.608423
# Epoch: 73
# Train loss 146 1.951930
# Validation loss 146:  2.646553
# Train loss 147 1.916871
# Validation loss 147:  2.161785
# Epoch: 74
# Train loss 148 1.894598
# Validation loss 148:  2.341983
# Train loss 149 1.885901
# Validation loss 149:  2.618047
# Epoch: 75
# Train loss 150 1.880000
# Validation loss 150:  2.271192
# Train loss 151 1.847058
# Validation loss 151:  2.120865
# Epoch: 76
# Train loss 152 1.871557
# Validation loss 152:  2.231584
# Train loss 153 1.832135
# Validation loss 153:  2.398410
# Epoch: 77
# Train loss 154 1.870790
# Validation loss 154:  2.271458
# Train loss 155 1.816803
# Validation loss 155:  2.466362
# Epoch: 78
# Train loss 156 1.895846
# Validation loss 156:  2.218457
# Train loss 157 1.834860
# Validation loss 157:  2.070010
# Epoch: 79
# Train loss 158 1.948563
# Validation loss 158:  2.388741
# Train loss 159 1.927760
# Validation loss 159:  2.856298
# Epoch: 80
# Train loss 160 1.945713
# Validation loss 160:  2.538672
# Train loss 161 1.860957
# Validation loss 161:  1.966470
# Epoch: 81
# Train loss 162 1.919587
# Validation loss 162:  1.934782
# Train loss 163 1.889062
# Validation loss 163:  2.139540
# Epoch: 82
# Train loss 164 1.876505
# Validation loss 164:  2.321829
# Train loss 165 1.820109
# Validation loss 165:  2.117280
# Epoch: 83
# Train loss 166 1.882039
# Validation loss 166:  2.165539
# Train loss 167 1.852189
# Validation loss 167:  2.248545
# Epoch: 84
# Train loss 168 1.843123
# Validation loss 168:  2.004381
# Train loss 169 1.807429
# Validation loss 169:  1.825612
# Epoch: 85
# Train loss 170 1.912171
# Validation loss 170:  1.834122
# Train loss 171 1.841804
# Validation loss 171:  2.094003
# Epoch: 86
# Train loss 172 1.819639
# Validation loss 172:  2.150087
# Train loss 173 1.791019
# Validation loss 173:  1.837627
# Epoch: 87
# Train loss 174 1.847112
# Validation loss 174:  1.809370
# Train loss 175 1.799265
# Validation loss 175:  2.099632
# Epoch: 88
# Train loss 176 1.852679
# Validation loss 176:  2.150517
# Train loss 177 1.828614
# Validation loss 177:  1.855072
# Epoch: 89
# Train loss 178 1.792692
# Validation loss 178:  1.882304
# Train loss 179 1.770899
# Validation loss 179:  2.043967
# Epoch: 90
# Train loss 180 1.855058
# Validation loss 180:  1.925965
# Train loss 181 1.817897
# Validation loss 181:  1.732290
# Epoch: 91
# Train loss 182 1.799338
# Validation loss 182:  1.804415
# Train loss 183 1.763207
# Validation loss 183:  2.188271
# Epoch: 92
# Train loss 184 1.817706
# Validation loss 184:  2.134499
# Train loss 185 1.779875
# Validation loss 185:  1.773457
# Epoch: 93
# Train loss 186 1.813441
# Validation loss 186:  1.749226
# Train loss 187 1.794245
# Validation loss 187:  1.871338
# Epoch: 94
# Train loss 188 1.779188
# Validation loss 188:  1.911801
# Train loss 189 1.738929
# Validation loss 189:  1.788962
# Epoch: 95
# Train loss 190 1.811495
# Validation loss 190:  1.819354
# Train loss 191 1.767974
# Validation loss 191:  2.072905
# Epoch: 96
# Train loss 192 1.795278
# Validation loss 192:  1.962532
# Train loss 193 1.754141
# Validation loss 193:  1.711629
# Epoch: 97
# Train loss 194 1.787626
# Validation loss 194:  1.723121
# Train loss 195 1.761736
# Validation loss 195:  1.945330
# Epoch: 98
# Train loss 196 1.791526
# Validation loss 196:  1.926190
# Train loss 197 1.757882
# Validation loss 197:  1.697009
# Epoch: 99
# Train loss 198 1.769109
# Validation loss 198:  1.707997
# Train loss 199 1.741886
# Validation loss 199:  1.925103
# Epoch: 100
# Train loss 200 1.776756
# Validation loss 200:  1.894506
# Train loss 201 1.740077
# Validation loss 201:  1.685276
# Epoch: 101
# Train loss 202 1.760274
# Validation loss 202:  1.693557
# Train loss 203 1.728921
# Validation loss 203:  1.880881
# Epoch: 102
# Train loss 204 1.771098
# Validation loss 204:  1.859028
# Train loss 205 1.736597
# Validation loss 205:  1.677199
# Epoch: 103
# Train loss 206 1.751054
# Validation loss 206:  1.693821
# Train loss 207 1.718207
# Validation loss 207:  1.869188
# Epoch: 104
# Train loss 208 1.769339
# Validation loss 208:  1.810812
# Train loss 209 1.724896
# Validation loss 209:  1.674856
# Epoch: 105
# Train loss 210 1.750566
# Validation loss 210:  1.693370
# Train loss 211 1.714732
# Validation loss 211:  1.894366
# Epoch: 106
# Train loss 212 1.752733
# Validation loss 212:  1.819614
# Train loss 213 1.704999
# Validation loss 213:  1.662068
# Epoch: 107
# Train loss 214 1.742133
# Validation loss 214:  1.655062
# Train loss 215 1.714044
# Validation loss 215:  1.804811
# Epoch: 108
# Train loss 216 1.733941
# Validation loss 216:  1.773644
# Train loss 217 1.697355
# Validation loss 217:  1.633603
# Epoch: 109
# Train loss 218 1.725448
# Validation loss 218:  1.624432
# Train loss 219 1.695192
# Validation loss 219:  1.798034
# Epoch: 110
# Train loss 220 1.745044
# Validation loss 220:  1.782746
# Train loss 221 1.705767
# Validation loss 221:  1.617547
# Epoch: 111
# Train loss 222 1.708403
# Validation loss 222:  1.615667
# Train loss 223 1.676869
# Validation loss 223:  1.720809
# Epoch: 112
# Train loss 224 1.719252
# Validation loss 224:  1.669369
# Train loss 225 1.679749
# Validation loss 225:  1.620026
# Epoch: 113
# Train loss 226 1.724657
# Validation loss 226:  1.633111
# Train loss 227 1.689046
# Validation loss 227:  1.726420
# Epoch: 114
# Train loss 228 1.684409
# Validation loss 228:  1.651675
# Train loss 229 1.653284
# Validation loss 229:  1.607807
# Epoch: 115
# Train loss 230 1.708846
# Validation loss 230:  1.619942
# Train loss 231 1.657715
# Validation loss 231:  1.739722
# Epoch: 116
# Train loss 232 1.693066
# Validation loss 232:  1.746669
# Train loss 233 1.689873
# Validation loss 233:  1.607286
# Epoch: 117
# Train loss 234 1.667735
# Validation loss 234:  1.663916
# Train loss 235 1.663490
# Validation loss 235:  1.618204
# Epoch: 118
# Train loss 236 1.656699
# Validation loss 236:  1.621592
# Train loss 237 1.677183
# Validation loss 237:  1.685255
# Epoch: 119
# Train loss 238 1.656302
# Validation loss 238:  1.842683
# Train loss 239 1.700219
# Validation loss 239:  1.718070
# Epoch: 120
# Train loss 240 1.740667
# Validation loss 240:  1.561865
# Train loss 241 1.632520
# Validation loss 241:  1.646181
# Epoch: 121
# Train loss 242 1.684225
# Validation loss 242:  1.724737
# Train loss 243 1.662703
# Validation loss 243:  1.649257
# Epoch: 122
# Train loss 244 1.639871
# Validation loss 244:  1.640562
# Train loss 245 1.624663
# Validation loss 245:  1.585683
# Epoch: 123
# Train loss 246 1.649210
# Validation loss 246:  1.700988
# Train loss 247 1.599373
# Validation loss 247:  1.756461
# Epoch: 124
# Train loss 248 1.630941
# Validation loss 248:  1.747818
# Train loss 249 1.583545
# Validation loss 249:  1.673687
# Epoch: 125
# Train loss 250 1.626860
# Validation loss 250:  1.611706
# Train loss 251 1.607015
# Validation loss 251:  1.771590
# Epoch: 126
# Train loss 252 1.589044
# Validation loss 252:  1.753727
# Train loss 253 1.596335
# Validation loss 253:  1.792619
# Epoch: 127
# Train loss 254 1.596631
# Validation loss 254:  1.677752
# Train loss 255 1.590099
# Validation loss 255:  1.569727
# Epoch: 128
# Train loss 256 1.664358
# Validation loss 256:  1.578332
# Train loss 257 1.583945
# Validation loss 257:  1.836601
# Epoch: 129
# Train loss 258 1.581782
# Validation loss 258:  1.905605
# Train loss 259 1.608843
# Validation loss 259:  1.661423
# Epoch: 130
# Train loss 260 1.615763
# Validation loss 260:  1.618457
# Train loss 261 1.522601
# Validation loss 261:  1.724181
# Epoch: 131
# Train loss 262 1.606604
# Validation loss 262:  1.644584
# Train loss 263 1.603220
# Validation loss 263:  1.556798
# Epoch: 132
# Train loss 264 1.646339
# Validation loss 264:  1.581024
# Train loss 265 1.562849
# Validation loss 265:  1.905062
# Epoch: 133
# Train loss 266 1.585773
# Validation loss 266:  1.935678
# Train loss 267 1.581436
# Validation loss 267:  1.664515
# Epoch: 134
# Train loss 268 1.588914
# Validation loss 268:  1.603290
# Train loss 269 1.522373
# Validation loss 269:  1.776186
# Epoch: 135
# Train loss 270 1.586465
# Validation loss 270:  1.676392
# Train loss 271 1.543137
# Validation loss 271:  1.537487
# Epoch: 136
# Train loss 272 1.590756
# Validation loss 272:  1.537741
# Train loss 273 1.549746
# Validation loss 273:  1.810867
# Epoch: 137
# Train loss 274 1.529224
# Validation loss 274:  1.861798
# Train loss 275 1.503659
# Validation loss 275:  1.593130
# Epoch: 138
# Train loss 276 1.546489
# Validation loss 276:  1.578732
# Train loss 277 1.507942
# Validation loss 277:  1.906131
# Epoch: 139
# Train loss 278 1.555548
# Validation loss 278:  2.021445
# Train loss 279 1.542707
# Validation loss 279:  1.727464
# Epoch: 140
# Train loss 280 1.495104
# Validation loss 280:  1.830916
# Train loss 281 1.481855
# Validation loss 281:  1.918060
# Epoch: 141
# Train loss 282 1.509967
# Validation loss 282:  1.655299
# Train loss 283 1.478716
# Validation loss 283:  1.605212
# Epoch: 142
# Train loss 284 1.527167
# Validation loss 284:  1.785528
# Train loss 285 1.482357
# Validation loss 285:  1.882336
# Epoch: 143
# Train loss 286 1.497881
# Validation loss 286:  1.703572
# Train loss 287 1.474087
# Validation loss 287:  1.703054
# Epoch: 144
# Train loss 288 1.473694
# Validation loss 288:  1.946782
# Train loss 289 1.504182
# Validation loss 289:  1.794446
# Epoch: 145
# Train loss 290 1.503892
# Validation loss 290:  1.533870
# Train loss 291 1.469006
# Validation loss 291:  1.614462
# Epoch: 146
# Train loss 292 1.505220
# Validation loss 292:  1.860189
# Train loss 293 1.446909
# Validation loss 293:  1.750898
# Epoch: 147
# Train loss 294 1.476847
# Validation loss 294:  1.626282
# Train loss 295 1.443863
# Validation loss 295:  1.699343
# Epoch: 148
# Train loss 296 1.457074
# Validation loss 296:  1.630631
# Train loss 297 1.462649
# Validation loss 297:  1.695794
# Epoch: 149
# Train loss 298 1.445451
# Validation loss 298:  1.664188
# Train loss 299 1.454240
# Validation loss 299:  1.697509
# Epoch: 150
# Train loss 300 1.454318
# Validation loss 300:  1.781893
# Train loss 301 1.463606
# Validation loss 301:  1.666748
# Epoch: 151
# Train loss 302 1.487744
# Validation loss 302:  1.597292
# Train loss 303 1.408725
# Validation loss 303:  1.635849
# Epoch: 152
# Train loss 304 1.471911
# Validation loss 304:  1.679716
# Train loss 305 1.418263
# Validation loss 305:  1.630896
# Epoch: 153
# Train loss 306 1.474329
# Validation loss 306:  1.650455
# Train loss 307 1.464949
# Validation loss 307:  1.554625
# Epoch: 154
# Train loss 308 1.428081
# Validation loss 308:  1.844994
# Train loss 309 1.466377
# Validation loss 309:  1.737606
# Epoch: 155
# Train loss 310 1.493627
# Validation loss 310:  1.526020
# Train loss 311 1.415488
# Validation loss 311:  1.676726
# Epoch: 156
# Train loss 312 1.484783
# Validation loss 312:  1.608551
# Train loss 313 1.491600
# Validation loss 313:  1.435251
# Epoch: 157
# Train loss 314 1.483683
# Validation loss 314:  1.478577
# Train loss 315 1.395690
# Validation loss 315:  1.861714
# Epoch: 158
# Train loss 316 1.477637
# Validation loss 316:  1.779386
# Train loss 317 1.449360
# Validation loss 317:  1.443783
# Epoch: 159
# Train loss 318 1.476082
# Validation loss 318:  1.377982
# Train loss 319 1.442254
# Validation loss 319:  1.519680
# Epoch: 160
# Train loss 320 1.448032
# Validation loss 320:  1.579750
# Train loss 321 1.433729
# Validation loss 321:  1.429662
# Epoch: 161
# Train loss 322 1.439601
# Validation loss 322:  1.465323
# Train loss 323 1.396304
# Validation loss 323:  1.661258
# Epoch: 162
# Train loss 324 1.430463
# Validation loss 324:  1.491996
# Train loss 325 1.388450
# Validation loss 325:  1.330319
# Epoch: 163
# Train loss 326 1.444467
# Validation loss 326:  1.321356
# Train loss 327 1.407901
# Validation loss 327:  1.428031
# Epoch: 164
# Train loss 328 1.427308
# Validation loss 328:  1.546693
# Train loss 329 1.378498
# Validation loss 329:  1.449701
# Epoch: 165
# Train loss 330 1.412937
# Validation loss 330:  1.498747
# Train loss 331 1.388122
# Validation loss 331:  1.631066
# Epoch: 166
# Train loss 332 1.416537
# Validation loss 332:  1.452636
# Train loss 333 1.378573
# Validation loss 333:  1.331699
# Epoch: 167
# Train loss 334 1.441285
# Validation loss 334:  1.341290
# Train loss 335 1.412407
# Validation loss 335:  1.417192
# Epoch: 168
# Train loss 336 1.380770
# Validation loss 336:  1.528820
# Train loss 337 1.365862
# Validation loss 337:  1.395927
# Epoch: 169
# Train loss 338 1.385613
# Validation loss 338:  1.415077
# Train loss 339 1.349342
# Validation loss 339:  1.578929
# Epoch: 170
# Train loss 340 1.426397
# Validation loss 340:  1.482143
# Train loss 341 1.397426
# Validation loss 341:  1.304631
# Epoch: 171
# Train loss 342 1.383528
# Validation loss 342:  1.354341
# Train loss 343 1.368603
# Validation loss 343:  1.467602
# Epoch: 172
# Train loss 344 1.377371
# Validation loss 344:  1.441070
# Train loss 345 1.369543
# Validation loss 345:  1.348665
# Epoch: 173
# Train loss 346 1.371015
# Validation loss 346:  1.430465
# Train loss 347 1.365201
# Validation loss 347:  1.376275
# Epoch: 174
# Train loss 348 1.377978
# Validation loss 348:  1.337746
# Train loss 349 1.378630
# Validation loss 349:  1.375665
# Epoch: 175
# Train loss 350 1.408718
# Validation loss 350:  1.406032
# Train loss 351 1.341856
# Validation loss 351:  1.358729
# Epoch: 176
# Train loss 352 1.386664
# Validation loss 352:  1.306815
# Train loss 353 1.336271
# Validation loss 353:  1.344489
# Epoch: 177
# Train loss 354 1.381240
# Validation loss 354:  1.305214
# Train loss 355 1.331895
# Validation loss 355:  1.292968
# Epoch: 178
# Train loss 356 1.367385
# Validation loss 356:  1.322526
# Train loss 357 1.352826
# Validation loss 357:  1.324744
# Epoch: 179
# Train loss 358 1.345383
# Validation loss 358:  1.310647
# Train loss 359 1.351383
# Validation loss 359:  1.312670
# Epoch: 180
# Train loss 360 1.349299
# Validation loss 360:  1.383904
# Train loss 361 1.339126
# Validation loss 361:  1.332465
# Epoch: 181
# Train loss 362 1.384580
# Validation loss 362:  1.274447
# Train loss 363 1.339077
# Validation loss 363:  1.274372
# Epoch: 182
# Train loss 364 1.343988
# Validation loss 364:  1.370253
# Train loss 365 1.347091
# Validation loss 365:  1.313442
# Epoch: 183
# Train loss 366 1.341854
# Validation loss 366:  1.309430
# Train loss 367 1.365593
# Validation loss 367:  1.327678
# Epoch: 184
# Train loss 368 1.398343
# Validation loss 368:  1.296257
# Train loss 369 1.320790
# Validation loss 369:  1.327076
# Epoch: 185
# Train loss 370 1.353020
# Validation loss 370:  1.322741
# Train loss 371 1.363987
# Validation loss 371:  1.261377
# Epoch: 186
# Train loss 372 1.336993
# Validation loss 372:  1.309304
# Train loss 373 1.329458
# Validation loss 373:  1.323783
# Epoch: 187
# Train loss 374 1.349909
# Validation loss 374:  1.261195
# Train loss 375 1.303029
# Validation loss 375:  1.281036
# Epoch: 188
# Train loss 376 1.330437
# Validation loss 376:  1.289707
# Train loss 377 1.296975
# Validation loss 377:  1.257426
# Epoch: 189
# Train loss 378 1.329705
# Validation loss 378:  1.274029
# Train loss 379 1.298457
# Validation loss 379:  1.283468
# Epoch: 190
# Train loss 380 1.316935
# Validation loss 380:  1.274561
# Train loss 381 1.285964
# Validation loss 381:  1.358926
# Epoch: 191
# Train loss 382 1.328356
# Validation loss 382:  1.289212
# Train loss 383 1.288832
# Validation loss 383:  1.255050
# Epoch: 192
# Train loss 384 1.326910
# Validation loss 384:  1.308628
# Train loss 385 1.314415
# Validation loss 385:  1.312512
# Epoch: 193
# Train loss 386 1.310761
# Validation loss 386:  1.281447
# Train loss 387 1.315167
# Validation loss 387:  1.294305
# Epoch: 194
# Train loss 388 1.336243
# Validation loss 388:  1.387433
# Train loss 389 1.302273
# Validation loss 389:  1.332094
# Epoch: 195
# Train loss 390 1.315995
# Validation loss 390:  1.278898
# Train loss 391 1.311105
# Validation loss 391:  1.278605
# Epoch: 196
# Train loss 392 1.323320
# Validation loss 392:  1.373285
# Train loss 393 1.300078
# Validation loss 393:  1.337873
# Epoch: 197
# Train loss 394 1.319872
# Validation loss 394:  1.254179
# Train loss 395 1.304791
# Validation loss 395:  1.253021
# Epoch: 198
# Train loss 396 1.312976
# Validation loss 396:  1.417337
# Train loss 397 1.305244
# Validation loss 397:  1.404039
# Epoch: 199
# Train loss 398 1.337451
# Validation loss 398:  1.244539
# Train loss 399 1.279186
# Validation loss 399:  1.227968
# Epoch: 200
# Train loss 400 1.301550
# Validation loss 400:  1.301313
# Train loss 401 1.279678
# Validation loss 401:  1.359565
# Epoch: 201
# Train loss 402 1.303007
# Validation loss 402:  1.263316
# Train loss 403 1.278379
# Validation loss 403:  1.248658
# Epoch: 202
# Train loss 404 1.296329
# Validation loss 404:  1.315362
# Train loss 405 1.277119
# Validation loss 405:  1.268236
# Epoch: 203
# Train loss 406 1.288239
# Validation loss 406:  1.240176
# Train loss 407 1.285843
# Validation loss 407:  1.251604
# Epoch: 204
# Train loss 408 1.296477
# Validation loss 408:  1.396183
# Train loss 409 1.282100
# Validation loss 409:  1.297477
# Epoch: 205
# Train loss 410 1.304463
# Validation loss 410:  1.251571
# Train loss 411 1.298078
# Validation loss 411:  1.258636
# Epoch: 206
# Train loss 412 1.317467
# Validation loss 412:  1.231698
# Train loss 413 1.259028
# Validation loss 413:  1.391185
# Epoch: 207
# Train loss 414 1.291495
# Validation loss 414:  1.293056
# Train loss 415 1.265733
# Validation loss 415:  1.247724
# Epoch: 208
# Train loss 416 1.289462
# Validation loss 416:  1.488363
# Train loss 417 1.299038
# Validation loss 417:  1.456653
# Epoch: 209
# Train loss 418 1.309746
# Validation loss 418:  1.266328
# Train loss 419 1.261706
# Validation loss 419:  1.230933
# Epoch: 210
# Train loss 420 1.285332
# Validation loss 420:  1.368165
# Train loss 421 1.273231
# Validation loss 421:  1.324331
# Epoch: 211
# Train loss 422 1.282137
# Validation loss 422:  1.258377
# Train loss 423 1.289190
# Validation loss 423:  1.278205
# Epoch: 212
# Train loss 424 1.327530
# Validation loss 424:  1.399739
# Train loss 425 1.256609
# Validation loss 425:  1.262671
# Epoch: 213
# Train loss 426 1.274247
# Validation loss 426:  1.203036
# Train loss 427 1.270938
# Validation loss 427:  1.218793
# Epoch: 214
# Train loss 428 1.262202
# Validation loss 428:  1.421702
# Train loss 429 1.253465
# Validation loss 429:  1.332986
# Epoch: 215
# Train loss 430 1.283090
# Validation loss 430:  1.249149
# Train loss 431 1.238020
# Validation loss 431:  1.265350
# Epoch: 216
# Train loss 432 1.285116
# Validation loss 432:  1.224026
# Train loss 433 1.274317
# Validation loss 433:  1.249928
# Epoch: 217
# Train loss 434 1.312532
# Validation loss 434:  1.217524
# Train loss 435 1.250250
# Validation loss 435:  1.276539
# Epoch: 218
# Train loss 436 1.300008
# Validation loss 436:  1.303260
# Train loss 437 1.299139
# Validation loss 437:  1.225238
# Epoch: 219
# Train loss 438 1.270991
# Validation loss 438:  1.191186
# Train loss 439 1.228716
# Validation loss 439:  1.220305
# Epoch: 220
# Train loss 440 1.287370
# Validation loss 440:  1.211691
# Train loss 441 1.258506
# Validation loss 441:  1.286288
# Epoch: 221
# Train loss 442 1.294762
# Validation loss 442:  1.255116
# Train loss 443 1.260025
# Validation loss 443:  1.186875
# Epoch: 222
# Train loss 444 1.251325
# Validation loss 444:  1.198577
# Train loss 445 1.228934
# Validation loss 445:  1.205971
# Epoch: 223
# Train loss 446 1.277086
# Validation loss 446:  1.195944
# Train loss 447 1.249240
# Validation loss 447:  1.210472
# Epoch: 224
# Train loss 448 1.262113
# Validation loss 448:  1.194480
# Train loss 449 1.226235
# Validation loss 449:  1.184403
# Epoch: 225
# Train loss 450 1.253247
# Validation loss 450:  1.175566
# Train loss 451 1.221809
# Validation loss 451:  1.286014
# Epoch: 226
# Train loss 452 1.280298
# Validation loss 452:  1.305631
# Train loss 453 1.259155
# Validation loss 453:  1.179319
# Epoch: 227
# Train loss 454 1.234492
# Validation loss 454:  1.158076
# Train loss 455 1.207102
# Validation loss 455:  1.192615
# Epoch: 228
# Train loss 456 1.251556
# Validation loss 456:  1.172933
# Train loss 457 1.217091
# Validation loss 457:  1.202459
# Epoch: 229
# Train loss 458 1.256939
# Validation loss 458:  1.186351
# Train loss 459 1.222177
# Validation loss 459:  1.214592
# Epoch: 230
# Train loss 460 1.223304
# Validation loss 460:  1.187828
# Train loss 461 1.195852
# Validation loss 461:  1.176684
# Epoch: 231
# Train loss 462 1.243668
# Validation loss 462:  1.156558
# Train loss 463 1.207313
# Validation loss 463:  1.247093
# Epoch: 232
# Train loss 464 1.267456
# Validation loss 464:  1.292378
# Train loss 465 1.253365
# Validation loss 465:  1.170049
# Epoch: 233
# Train loss 466 1.213020
# Validation loss 466:  1.203857
# Train loss 467 1.242507
# Validation loss 467:  1.184819
# Epoch: 234
# Train loss 468 1.248248
# Validation loss 468:  1.191738
# Train loss 469 1.219729
# Validation loss 469:  1.218427
# Epoch: 235
# Train loss 470 1.268226
# Validation loss 470:  1.170021
# Train loss 471 1.207400
# Validation loss 471:  1.172435
# Epoch: 236
# Train loss 472 1.226589
# Validation loss 472:  1.193948
# Train loss 473 1.204449
# Validation loss 473:  1.158725
# Epoch: 237
# Train loss 474 1.218330
# Validation loss 474:  1.163063
# Train loss 475 1.200397
# Validation loss 475:  1.167955
# Epoch: 238
# Train loss 476 1.209906
# Validation loss 476:  1.162651
# Train loss 477 1.208796
# Validation loss 477:  1.149384
# Epoch: 239
# Train loss 478 1.202121
# Validation loss 478:  1.208336
# Train loss 479 1.199283
# Validation loss 479:  1.173877
# Epoch: 240
# Train loss 480 1.223234
# Validation loss 480:  1.149296
# Train loss 481 1.175625
# Validation loss 481:  1.171411
# Epoch: 241
# Train loss 482 1.215459
# Validation loss 482:  1.159664
# Train loss 483 1.191018
# Validation loss 483:  1.152120
# Epoch: 242
# Train loss 484 1.195218
# Validation loss 484:  1.157509
# Train loss 485 1.179358
# Validation loss 485:  1.151834
# Epoch: 243
# Train loss 486 1.206277
# Validation loss 486:  1.138745
# Train loss 487 1.172697
# Validation loss 487:  1.136702
# Epoch: 244
# Train loss 488 1.186662
# Validation loss 488:  1.158205
# Train loss 489 1.172379
# Validation loss 489:  1.135116
# Epoch: 245
# Train loss 490 1.184787
# Validation loss 490:  1.128184
# Train loss 491 1.169544
# Validation loss 491:  1.165128
# Epoch: 246
# Train loss 492 1.191801
# Validation loss 492:  1.138767
# Train loss 493 1.157077
# Validation loss 493:  1.129810
# Epoch: 247
# Train loss 494 1.175610
# Validation loss 494:  1.180104
# Train loss 495 1.182621
# Validation loss 495:  1.129205
# Epoch: 248
# Train loss 496 1.178136
# Validation loss 496:  1.226717
# Train loss 497 1.232675
# Validation loss 497:  1.226868
# Epoch: 249
# Train loss 498 1.261786
# Validation loss 498:  1.156466
# Train loss 499 1.170796
# Validation loss 499:  1.250080
# Epoch: 250
# Train loss 500 1.213469
# Validation loss 500:  1.202525
# Train loss 501 1.202645
# Validation loss 501:  1.148870
# Epoch: 251
# Train loss 502 1.202118
# Validation loss 502:  1.144375
# Train loss 503 1.169655
# Validation loss 503:  1.204018
# Epoch: 252
# Train loss 504 1.206975
# Validation loss 504:  1.176360
# Train loss 505 1.173377
# Validation loss 505:  1.158010
# Epoch: 253
# Train loss 506 1.209355
# Validation loss 506:  1.137709
# Train loss 507 1.181037
# Validation loss 507:  1.152737
# Epoch: 254
# Train loss 508 1.191073
# Validation loss 508:  1.158904
# Train loss 509 1.161945
# Validation loss 509:  1.132997
# Epoch: 255
# Train loss 510 1.176681
# Validation loss 510:  1.127011
# Train loss 511 1.148502
# Validation loss 511:  1.191136
# Epoch: 256
# Train loss 512 1.195078
# Validation loss 512:  1.148477
# Train loss 513 1.161963
# Validation loss 513:  1.132393
# Epoch: 257
# Train loss 514 1.181906
# Validation loss 514:  1.114778
# Train loss 515 1.150601
# Validation loss 515:  1.178907
# Epoch: 258
# Train loss 516 1.175354
# Validation loss 516:  1.162669
# Train loss 517 1.149511
# Validation loss 517:  1.138449
# Epoch: 259
# Train loss 518 1.172687
# Validation loss 518:  1.148716
# Train loss 519 1.161128
# Validation loss 519:  1.099718
# Epoch: 260
# Train loss 520 1.159415
# Validation loss 520:  1.097086
# Train loss 521 1.122491
# Validation loss 521:  1.119316
# Epoch: 261
# Train loss 522 1.165086
# Validation loss 522:  1.109855
# Train loss 523 1.129820
# Validation loss 523:  1.131660
# Epoch: 262
# Train loss 524 1.168846
# Validation loss 524:  1.112276
# Train loss 525 1.144642
# Validation loss 525:  1.120928
# Epoch: 263
# Train loss 526 1.155379
# Validation loss 526:  1.093154
# Train loss 527 1.124640
# Validation loss 527:  1.166333
# Epoch: 264
# Train loss 528 1.163335
# Validation loss 528:  1.141758
# Train loss 529 1.128943
# Validation loss 529:  1.116206
# Epoch: 265
# Train loss 530 1.156652
# Validation loss 530:  1.124540
# Train loss 531 1.134168
# Validation loss 531:  1.082348
# Epoch: 266
# Train loss 532 1.141070
# Validation loss 532:  1.088746
# Train loss 533 1.112962
# Validation loss 533:  1.104676
# Epoch: 267
# Train loss 534 1.145443
# Validation loss 534:  1.091144
# Train loss 535 1.113830
# Validation loss 535:  1.111066
# Epoch: 268
# Train loss 536 1.148759
# Validation loss 536:  1.082251
# Train loss 537 1.117515
# Validation loss 537:  1.128077
# Epoch: 269
# Train loss 538 1.140515
# Validation loss 538:  1.105596
# Train loss 539 1.112281
# Validation loss 539:  1.105830
# Epoch: 270
# Train loss 540 1.139750
# Validation loss 540:  1.100501
# Train loss 541 1.120727
# Validation loss 541:  1.095607
# Epoch: 271
# Train loss 542 1.136904
# Validation loss 542:  1.096273
# Train loss 543 1.106620
# Validation loss 543:  1.080582
# Epoch: 272
# Train loss 544 1.129834
# Validation loss 544:  1.073456
# Train loss 545 1.105590
# Validation loss 545:  1.102919
# Epoch: 273
# Train loss 546 1.134740
# Validation loss 546:  1.091554
# Train loss 547 1.112915
# Validation loss 547:  1.077361
# Epoch: 274
# Train loss 548 1.121929
# Validation loss 548:  1.065503
# Train loss 549 1.093353
# Validation loss 549:  1.096665
# Epoch: 275
# Train loss 550 1.136636
# Validation loss 550:  1.081186
# Train loss 551 1.103721
# Validation loss 551:  1.085221
# Epoch: 276
# Train loss 552 1.118401
# Validation loss 552:  1.081686
# Train loss 553 1.098659
# Validation loss 553:  1.075462
# Epoch: 277
# Train loss 554 1.121088
# Validation loss 554:  1.073221
# Train loss 555 1.092905
# Validation loss 555:  1.095582
# Epoch: 278
# Train loss 556 1.114764
# Validation loss 556:  1.093877
# Train loss 557 1.098570
# Validation loss 557:  1.065197
# Epoch: 279
# Train loss 558 1.112523
# Validation loss 558:  1.066074
# Train loss 559 1.101049
# Validation loss 559:  1.044544
# Epoch: 280
# Train loss 560 1.094896
# Validation loss 560:  1.054822
# Train loss 561 1.085190
# Validation loss 561:  1.038773
# Epoch: 281
# Train loss 562 1.100857
# Validation loss 562:  1.095835
# Train loss 563 1.095523
# Validation loss 563:  1.055806
# Epoch: 282
# Train loss 564 1.097946
# Validation loss 564:  1.108079
# Train loss 565 1.115713
# Validation loss 565:  1.115162
# Epoch: 283
# Train loss 566 1.141067
# Validation loss 566:  1.078254
# Train loss 567 1.103080
# Validation loss 567:  1.055472
# Epoch: 284
# Train loss 568 1.099482
# Validation loss 568:  1.079840
# Train loss 569 1.104973
# Validation loss 569:  1.060931
# Epoch: 285
# Train loss 570 1.112055
# Validation loss 570:  1.095912
# Train loss 571 1.105546
# Validation loss 571:  1.070041
# Epoch: 286
# Train loss 572 1.107733
# Validation loss 572:  1.078711
# Train loss 573 1.087373
# Validation loss 573:  1.051412
# Epoch: 287
# Train loss 574 1.099175
# Validation loss 574:  1.082466
# Train loss 575 1.092905
# Validation loss 575:  1.068298
# Epoch: 288
# Train loss 576 1.097440
# Validation loss 576:  1.056333
# Train loss 577 1.073933
# Validation loss 577:  1.047110
# Epoch: 289
# Train loss 578 1.084163
# Validation loss 578:  1.044580
# Train loss 579 1.075908
# Validation loss 579:  1.032848
# Epoch: 290
# Train loss 580 1.079890
# Validation loss 580:  1.088387
# Train loss 581 1.084656
# Validation loss 581:  1.067182
# Epoch: 291
# Train loss 582 1.087551
# Validation loss 582:  1.046483
# Train loss 583 1.063214
# Validation loss 583:  1.044080
# Epoch: 292
# Train loss 584 1.070460
# Validation loss 584:  1.051296
# Train loss 585 1.079111
# Validation loss 585:  1.050369
# Epoch: 293
# Train loss 586 1.080207
# Validation loss 586:  1.050850
# Train loss 587 1.069460
# Validation loss 587:  1.059574
# Epoch: 294
# Train loss 588 1.092533
# Validation loss 588:  1.027039
# Train loss 589 1.051793
# Validation loss 589:  1.022421
# Epoch: 295
# Train loss 590 1.062254
# Validation loss 590:  1.028538
# Train loss 591 1.056601
# Validation loss 591:  1.020432
# Epoch: 296
# Train loss 592 1.064634
# Validation loss 592:  1.050523
# Train loss 593 1.067713
# Validation loss 593:  1.050386
# Epoch: 297
# Train loss 594 1.085918
# Validation loss 594:  1.043090
# Train loss 595 1.052567
# Validation loss 595:  1.030385
# Epoch: 298
# Train loss 596 1.063742
# Validation loss 596:  1.058702
# Train loss 597 1.054548
# Validation loss 597:  1.035446
# Epoch: 299
# Train loss 598 1.064748
# Validation loss 598:  1.047298
# Train loss 599 1.053788
# Validation loss 599:  1.055702
# Epoch: 300
# Train loss 600 1.064332
# Validation loss 600:  1.035743
# Train loss 601 1.058127
# Validation loss 601:  1.055859
# Epoch: 301
# Train loss 602 1.078309
# Validation loss 602:  1.002426
# Train loss 603 1.031292
# Validation loss 603:  1.032740
# Epoch: 302
# Train loss 604 1.053885
# Validation loss 604:  1.006005
# Train loss 605 1.044440
# Validation loss 605:  0.998202
# Epoch: 303
# Train loss 606 1.042279
# Validation loss 606:  1.014195
# Train loss 607 1.035029
# Validation loss 607:  1.004491
# Epoch: 304
# Train loss 608 1.040865
# Validation loss 608:  0.998833
# Train loss 609 1.029883
# Validation loss 609:  1.044064
# Epoch: 305
# Train loss 610 1.038988
# Validation loss 610:  1.002651
# Train loss 611 1.021053
# Validation loss 611:  1.000459
# Epoch: 306
# Train loss 612 1.033553
# Validation loss 612:  0.994927
# Train loss 613 1.016612
# Validation loss 613:  1.015538
# Epoch: 307
# Train loss 614 1.020603
# Validation loss 614:  1.016856
# Train loss 615 1.015317
# Validation loss 615:  0.992827
# Epoch: 308
# Train loss 616 1.020200
# Validation loss 616:  1.013284
# Train loss 617 1.013136
# Validation loss 617:  0.980133
# Epoch: 309
# Train loss 618 1.013106
# Validation loss 618:  0.984809
# Train loss 619 1.000645
# Validation loss 619:  1.024078
# Epoch: 310
# Train loss 620 1.013379
# Validation loss 620:  0.987271
# Train loss 621 1.006117
# Validation loss 621:  0.997400
# Epoch: 311
# Train loss 622 1.012528
# Validation loss 622:  0.970994
# Train loss 623 0.988699
# Validation loss 623:  0.972168
# Epoch: 312
# Train loss 624 1.000201
# Validation loss 624:  0.972683
# Train loss 625 0.985362
# Validation loss 625:  0.987258
# Epoch: 313
# Train loss 626 1.005847
# Validation loss 626:  0.978149
# Train loss 627 1.001537
# Validation loss 627:  0.961456
# Epoch: 314
# Train loss 628 0.996246
# Validation loss 628:  1.008216
# Train loss 629 0.995793
# Validation loss 629:  0.967568
# Epoch: 315
# Train loss 630 0.986866
# Validation loss 630:  0.963757
# Train loss 631 0.982103
# Validation loss 631:  0.996003
# Epoch: 316
# Train loss 632 1.013355
# Validation loss 632:  0.956169
# Train loss 633 0.976464
# Validation loss 633:  1.083759
# Epoch: 317
# Train loss 634 1.075983
# Validation loss 634:  1.074641
# Train loss 635 1.066234
# Validation loss 635:  0.963128
# Epoch: 318
# Train loss 636 0.993735
# Validation loss 636:  1.095000
# Train loss 637 1.067195
# Validation loss 637:  1.118372
# Epoch: 319
# Train loss 638 1.119841
# Validation loss 638:  1.015417
# Train loss 639 1.015733
# Validation loss 639:  1.042673
# Epoch: 320
# Train loss 640 1.044338
# Validation loss 640:  1.084784
# Train loss 641 1.101989
# Validation loss 641:  1.065903
# Epoch: 321
# Train loss 642 1.064098
# Validation loss 642:  1.021814
# Train loss 643 0.995185
# Validation loss 643:  1.038827
# Epoch: 322
# Train loss 644 1.052847
# Validation loss 644:  1.049775
# Train loss 645 1.023679
# Validation loss 645:  1.104285
# Epoch: 323
# Train loss 646 1.022772
# Validation loss 646:  1.031121
# Train loss 647 1.000097
# Validation loss 647:  1.036157
# Epoch: 324
# Train loss 648 1.005897
# Validation loss 648:  1.078047
# Train loss 649 0.991167
# Validation loss 649:  1.013212
# Epoch: 325
# Train loss 650 0.997485
# Validation loss 650:  1.010869
# Train loss 651 0.975052
# Validation loss 651:  0.997526
# Epoch: 326
# Train loss 652 0.993110
# Validation loss 652:  0.984392
# Train loss 653 0.966189
# Validation loss 653:  1.033907
# Epoch: 327
# Train loss 654 0.988184
# Validation loss 654:  0.989191
# Train loss 655 0.968582
# Validation loss 655:  0.966770
# Epoch: 328
# Train loss 656 0.973316
# Validation loss 656:  0.963464
# Train loss 657 0.962913
# Validation loss 657:  0.946425
# Epoch: 329
# Train loss 658 0.977765
# Validation loss 658:  0.961615
# Train loss 659 0.967196
# Validation loss 659:  0.944807
# Epoch: 330
# Train loss 660 0.967767
# Validation loss 660:  0.943351
# Train loss 661 0.959210
# Validation loss 661:  0.982527
# Epoch: 331
# Train loss 662 0.974715
# Validation loss 662:  0.949468
# Train loss 663 0.949459
# Validation loss 663:  0.940612
# Epoch: 332
# Train loss 664 0.958826
# Validation loss 664:  0.935639
# Train loss 665 0.943410
# Validation loss 665:  0.941293
# Epoch: 333
# Train loss 666 0.964419
# Validation loss 666:  0.926955
# Train loss 667 0.936685
# Validation loss 667:  0.945518
# Epoch: 334
# Train loss 668 0.961836
# Validation loss 668:  0.934114
# Train loss 669 0.939309
# Validation loss 669:  0.930958
# Epoch: 335
# Train loss 670 0.956021
# Validation loss 670:  0.926030
# Train loss 671 0.933275
# Validation loss 671:  0.914273
# Epoch: 336
# Train loss 672 0.943727
# Validation loss 672:  0.929296
# Train loss 673 0.941182
# Validation loss 673:  0.950528
# Epoch: 337
# Train loss 674 0.963042
# Validation loss 674:  0.919830
# Train loss 675 0.929751
# Validation loss 675:  0.933856
# Epoch: 338
# Train loss 676 0.942960
# Validation loss 676:  0.921708
# Train loss 677 0.932317
# Validation loss 677:  0.915916
# Epoch: 339
# Train loss 678 0.947558
# Validation loss 678:  0.927185
# Train loss 679 0.930598
# Validation loss 679:  0.921284
# Epoch: 340
# Train loss 680 0.940703
# Validation loss 680:  0.910002
# Train loss 681 0.917703
# Validation loss 681:  0.925262
# Epoch: 341
# Train loss 682 0.932441
# Validation loss 682:  0.915713
# Train loss 683 0.922023
# Validation loss 683:  0.906562
# Epoch: 342
# Train loss 684 0.923673
# Validation loss 684:  0.906785
# Train loss 685 0.913794
# Validation loss 685:  0.931452
# Epoch: 343
# Train loss 686 0.944781
# Validation loss 686:  0.909271
# Train loss 687 0.907929
# Validation loss 687:  0.931350
# Epoch: 344
# Train loss 688 0.943244
# Validation loss 688:  0.916737
# Train loss 689 0.917199
# Validation loss 689:  0.940231
# Epoch: 345
# Train loss 690 0.943185
# Validation loss 690:  0.936083
# Train loss 691 0.932778
# Validation loss 691:  0.921844
# Epoch: 346
# Train loss 692 0.934153
# Validation loss 692:  0.931777
# Train loss 693 0.927624
# Validation loss 693:  0.916654
# Epoch: 347
# Train loss 694 0.926876
# Validation loss 694:  0.927633
# Train loss 695 0.924123
# Validation loss 695:  0.910410
# Epoch: 348
# Train loss 696 0.924277
# Validation loss 696:  0.939075
# Train loss 697 0.930197
# Validation loss 697:  0.925627
# Epoch: 349
# Train loss 698 0.943811
# Validation loss 698:  0.967391
# Train loss 699 0.919867
# Validation loss 699:  0.929102
# Epoch: 350
# Train loss 700 0.926910
# Validation loss 700:  0.940399
# Train loss 701 0.924534
# Validation loss 701:  0.929570
# Epoch: 351
# Train loss 702 0.927280
# Validation loss 702:  0.943874
# Train loss 703 0.929828
# Validation loss 703:  0.954839
# Epoch: 352
# Train loss 704 0.947581
# Validation loss 704:  0.911187
# Train loss 705 0.914530
# Validation loss 705:  0.931006
# Epoch: 353
# Train loss 706 0.923012
# Validation loss 706:  0.897690
# Train loss 707 0.899463
# Validation loss 707:  0.893329
# Epoch: 354
# Train loss 708 0.907672
# Validation loss 708:  0.910166
# Train loss 709 0.904738
# Validation loss 709:  0.893868
# Epoch: 355
# Train loss 710 0.907341
# Validation loss 710:  0.938952
# Train loss 711 0.918578
# Validation loss 711:  0.908338
# Epoch: 356
# Train loss 712 0.918331
# Validation loss 712:  0.935896
# Train loss 713 0.906497
# Validation loss 713:  0.920550
# Epoch: 357
# Train loss 714 0.915724
# Validation loss 714:  0.911675
# Train loss 715 0.891072
# Validation loss 715:  0.899130
# Epoch: 358
# Train loss 716 0.896696
# Validation loss 716:  0.932007
# Train loss 717 0.908225
# Validation loss 717:  0.918922
# Epoch: 359
# Train loss 718 0.907789
# Validation loss 718:  0.893763
# Train loss 719 0.893878
# Validation loss 719:  0.892456
# Epoch: 360
# Train loss 720 0.902683
# Validation loss 720:  0.907179
# Train loss 721 0.888427
# Validation loss 721:  0.900837
# Epoch: 361
# Train loss 722 0.890328
# Validation loss 722:  0.891759
# Train loss 723 0.890288
# Validation loss 723:  0.882118
# Epoch: 362
# Train loss 724 0.888887
# Validation loss 724:  0.908976
# Train loss 725 0.886788
# Validation loss 725:  0.888340
# Epoch: 363
# Train loss 726 0.892822
# Validation loss 726:  0.909386
# Train loss 727 0.884340
# Validation loss 727:  0.863280
# Epoch: 364
# Train loss 728 0.878878
# Validation loss 728:  0.968486
# Train loss 729 0.885799
# Validation loss 729:  0.911915
# Epoch: 365
# Train loss 730 0.885444
# Validation loss 730:  0.894706
# Train loss 731 0.885929
# Validation loss 731:  0.885103
# Epoch: 366
# Train loss 732 0.892446
# Validation loss 732:  0.922700
# Train loss 733 0.871297
# Validation loss 733:  0.966677
# Epoch: 367
# Train loss 734 0.883632
# Validation loss 734:  0.874586
# Train loss 735 0.876950
# Validation loss 735:  0.877908
# Epoch: 368
# Train loss 736 0.887802
# Validation loss 736:  0.892032
# Train loss 737 0.866709
# Validation loss 737:  0.914991
# Epoch: 369
# Train loss 738 0.883577
# Validation loss 738:  0.864144
# Train loss 739 0.861398
# Validation loss 739:  0.865227
# Epoch: 370
# Train loss 740 0.872267
# ...
# Validation loss 790:  0.821435
# Train loss 791 0.794638
# Validation loss 791:  0.815389
# Epoch: 396
# Train loss 792 0.793891
# Validation loss 792:  0.836118
# Train loss 793 0.799910
# Validation loss 793:  0.810759
# Epoch: 397
# Train loss 794 0.796728
# Validation loss 794:  0.816748
# Train loss 795 0.785273
# Validation loss 795:  0.822106
# Epoch: 398
# Train loss 796 0.786667
# Validation loss 796:  0.817127
# Train loss 797 0.789894
# Validation loss 797:  0.815913
# Epoch: 399
# Train loss 798 0.784891
# Validation loss 798:  0.813159
# Train loss 799 0.779204
# Validation loss 799:  0.809516
# Epoch: 400
# Train loss 800 0.779943
# Validation loss 800:  0.821202
# Train loss 801 0.775791
# Validation loss 801:  0.805043
# Epoch: 401
# Train loss 802 0.787588
# Validation loss 802:  0.814430
# Train loss 803 0.773958
# Validation loss 803:  0.808677
# Epoch: 402
# Train loss 804 0.775153
# Validation loss 804:  0.804097
# Train loss 805 0.769218
# Validation loss 805:  0.841842
# Epoch: 403
# Train loss 806 0.793457
# Validation loss 806:  0.800969
# Train loss 807 0.765025
# Validation loss 807:  0.798599
# Epoch: 404
# Train loss 808 0.770671
# Validation loss 808:  0.815246
# Train loss 809 0.766237
# Validation loss 809:  0.803040
# Epoch: 405
# Train loss 810 0.769360
# Validation loss 810:  0.798427
# Train loss 811 0.755118
# Validation loss 811:  0.822565
# Epoch: 406
# Train loss 812 0.776648
# Validation loss 812:  0.813082
# Train loss 813 0.771213
# Validation loss 813:  0.801598
# Epoch: 407
# Train loss 814 0.763663
# Validation loss 814:  0.802934
# Train loss 815 0.756218
# Validation loss 815:  0.827547
# Epoch: 408
# Train loss 816 0.770987
# Validation loss 816:  0.803500
# Train loss 817 0.756971
# Validation loss 817:  0.799576
# Epoch: 409
# Train loss 818 0.760913
# Validation loss 818:  0.793035
# Train loss 819 0.753250
# Validation loss 819:  0.817368
# Epoch: 410
# Train loss 820 0.772256
# Validation loss 820:  0.783036
# Train loss 821 0.742935
# Validation loss 821:  0.783552
# Epoch: 411
# Train loss 822 0.754798
# Validation loss 822:  0.793857
# Train loss 823 0.739265
# Validation loss 823:  0.786891
# Epoch: 412
# Train loss 824 0.747370
# Validation loss 824:  0.784730
# Train loss 825 0.734175
# Validation loss 825:  0.799359
# Epoch: 413
# Train loss 826 0.750314
# Validation loss 826:  0.787748
# Train loss 827 0.738742
# Validation loss 827:  0.793230
# Epoch: 414
# Train loss 828 0.750880
# Validation loss 828:  0.780043
# Train loss 829 0.733615
# Validation loss 829:  0.795729
# Epoch: 415
# Train loss 830 0.745042
# Validation loss 830:  0.803603
# Train loss 831 0.744988
# Validation loss 831:  0.784014
# Epoch: 416
# Train loss 832 0.742996
# Validation loss 832:  0.791806
# Train loss 833 0.736833
# Validation loss 833:  0.788587
# Epoch: 417
# Train loss 834 0.740020
# Validation loss 834:  0.780306
# Train loss 835 0.724421
# Validation loss 835:  0.782187
# Epoch: 418
# Train loss 836 0.732609
# Validation loss 836:  0.781567
# Train loss 837 0.722977
# Validation loss 837:  0.787459
# Epoch: 419
# Train loss 838 0.731296
# Validation loss 838:  0.796676
# Train loss 839 0.726561
# Validation loss 839:  0.771446
# Epoch: 420
# Train loss 840 0.721034
# Validation loss 840:  0.772404
# Train loss 841 0.719783
# Validation loss 841:  0.809025
# Epoch: 421
# Train loss 842 0.734266
# Validation loss 842:  0.771364
# Train loss 843 0.710566
# Validation loss 843:  0.779037
# Epoch: 422
# Train loss 844 0.726656
# Validation loss 844:  0.784457
# Train loss 845 0.718028
# Validation loss 845:  0.775791
# Epoch: 423
# Train loss 846 0.715791
# Validation loss 846:  0.772240
# Train loss 847 0.706962
# Validation loss 847:  0.806900
# Epoch: 424
# Train loss 848 0.733328
# Validation loss 848:  0.768792
# Train loss 849 0.703790
# Validation loss 849:  0.779267
# Epoch: 425
# Train loss 850 0.723673
# Validation loss 850:  0.798236
# Train loss 851 0.713470
# Validation loss 851:  0.773864
# Epoch: 426
# Train loss 852 0.710913
# Validation loss 852:  0.791636
# Train loss 853 0.728574
# Validation loss 853:  0.767245
# Epoch: 427
# Train loss 854 0.710218
# Validation loss 854:  0.851164
# Train loss 855 0.734737
# Validation loss 855:  0.815836
# Epoch: 428
# Train loss 856 0.735983
# Validation loss 856:  0.806149
# Train loss 857 0.722233
# Validation loss 857:  0.772196
# Epoch: 429
# Train loss 858 0.714269
# Validation loss 858:  0.843005
# Train loss 859 0.736879
# Validation loss 859:  0.783253
# Epoch: 430
# Train loss 860 0.714689
# Validation loss 860:  0.866439
# Train loss 861 0.750770
# Validation loss 861:  0.841024
# Epoch: 431
# Train loss 862 0.768313
# Validation loss 862:  0.790247
# Train loss 863 0.704047
# Validation loss 863:  0.811237
# Epoch: 432
# Train loss 864 0.732100
# Validation loss 864:  0.771618
# Train loss 865 0.708802
# Validation loss 865:  0.784674
# Epoch: 433
# Train loss 866 0.728536
# Validation loss 866:  0.795853
# Train loss 867 0.707668
# Validation loss 867:  0.788860
# Epoch: 434
# Train loss 868 0.723394
# Validation loss 868:  0.790522
# Train loss 869 0.712260
# Validation loss 869:  0.780071
# Epoch: 435
# Train loss 870 0.718254
# Validation loss 870:  0.762582
# Train loss 871 0.700962
# Validation loss 871:  0.783403
# Epoch: 436
# Train loss 872 0.708344
# Validation loss 872:  0.806144
# Train loss 873 0.694749
# Validation loss 873:  0.760835
# Epoch: 437
# Train loss 874 0.694069
# Validation loss 874:  0.755473
# Train loss 875 0.687739
# Validation loss 875:  0.771363
# Epoch: 438
# Train loss 876 0.699426
# Validation loss 876:  0.764164
# Train loss 877 0.682828
# Validation loss 877:  0.755738
# Epoch: 439
# Train loss 878 0.688061
# Validation loss 878:  0.777945
# Train loss 879 0.686032
# Validation loss 879:  0.760441
# Epoch: 440
# Train loss 880 0.685180
# Validation loss 880:  0.761475
# Train loss 881 0.669938
# Validation loss 881:  0.766720
# Epoch: 441
# Train loss 882 0.680149
# Validation loss 882:  0.748937
# Train loss 883 0.669090
# Validation loss 883:  0.747838
# Epoch: 442
# Train loss 884 0.672385
# Validation loss 884:  0.760735
# Train loss 885 0.671227
# Validation loss 885:  0.764902
# Epoch: 443
# Train loss 886 0.675509
# Validation loss 886:  0.753314
# Train loss 887 0.659412
# Validation loss 887:  0.751071
# Epoch: 444
# Train loss 888 0.672909
# Validation loss 888:  0.758317
# Train loss 889 0.666215
# Validation loss 889:  0.762557
# Epoch: 445
# Train loss 890 0.674883
# Validation loss 890:  0.742794
# Train loss 891 0.657763
# Validation loss 891:  0.743041
# Epoch: 446
# Train loss 892 0.668453
# Validation loss 892:  0.762957
# Train loss 893 0.664473
# Validation loss 893:  0.739398
# Epoch: 447
# Train loss 894 0.660753
# Validation loss 894:  0.743436
# Train loss 895 0.649011
# Validation loss 895:  0.761032
# Epoch: 448
# Train loss 896 0.662462
# Validation loss 896:  0.745352
# Train loss 897 0.648727
# Validation loss 897:  0.740529
# Epoch: 449
# Train loss 898 0.653720
# Validation loss 898:  0.755764
# Train loss 899 0.647483
# Validation loss 899:  0.739700
# Epoch: 450
# Train loss 900 0.650511
# Validation loss 900:  0.746007
# Train loss 901 0.637955
# Validation loss 901:  0.750491
# Epoch: 451
# Train loss 902 0.648778
# Validation loss 902:  0.737585
# Train loss 903 0.639614
# Validation loss 903:  0.747899
# Epoch: 452
# Train loss 904 0.645600
# Validation loss 904:  0.751859
# Train loss 905 0.637873
# Validation loss 905:  0.737190
# Epoch: 453
# Train loss 906 0.639304
# Validation loss 906:  0.754348
# Train loss 907 0.632498
# Validation loss 907:  0.742487
# Epoch: 454
# Train loss 908 0.641897
# Validation loss 908:  0.743830
# Train loss 909 0.627100
# Validation loss 909:  0.751539
# Epoch: 455
# Train loss 910 0.642509
# Validation loss 910:  0.739904
# Train loss 911 0.635435
# Validation loss 911:  0.758364
# Epoch: 456
# Train loss 912 0.645828
# Validation loss 912:  0.736428
# Train loss 913 0.627512
# Validation loss 913:  0.739628
# Epoch: 457
# Train loss 914 0.638072
# Validation loss 914:  0.765337
# Train loss 915 0.646611
# Validation loss 915:  0.736675
# Epoch: 458
# Train loss 916 0.628741
# Validation loss 916:  0.732831
# Train loss 917 0.625267
# Validation loss 917:  0.741105
# Epoch: 459
# Train loss 918 0.633616
# Validation loss 918:  0.737458
# Train loss 919 0.615928
# Validation loss 919:  0.737160
# Epoch: 460
# Train loss 920 0.633681
# Validation loss 920:  0.763039
# Train loss 921 0.627462
# Validation loss 921:  0.740589
# Epoch: 461
# Train loss 922 0.627192
# Validation loss 922:  0.740065
# Train loss 923 0.623765
# Validation loss 923:  0.760405
# Epoch: 462
# Train loss 924 0.633821
# Validation loss 924:  0.732569
# Train loss 925 0.611688
# Validation loss 925:  0.741349
# Epoch: 463
# Train loss 926 0.626388
# Validation loss 926:  0.756280
# Train loss 927 0.621206
# Validation loss 927:  0.727484
# Epoch: 464
# Train loss 928 0.624341
# Validation loss 928:  0.733567
# Train loss 929 0.606962
# Validation loss 929:  0.742683
# Epoch: 465
# Train loss 930 0.621892
# Validation loss 930:  0.745361
# Train loss 931 0.610869
# Validation loss 931:  0.740595
# Epoch: 466
# Train loss 932 0.611730
# Validation loss 932:  0.743616
# Train loss 933 0.602822
# Validation loss 933:  0.729426
# Epoch: 467
# Train loss 934 0.614130
# Validation loss 934:  0.730291
# Train loss 935 0.596628
# Validation loss 935:  0.732398
# Epoch: 468
# Train loss 936 0.608910
# Validation loss 936:  0.734537
# Train loss 937 0.602166
# Validation loss 937:  0.743787
# Epoch: 469
# Train loss 938 0.607389
# Validation loss 938:  0.728479
# Train loss 939 0.595546
# Validation loss 939:  0.735472
# Epoch: 470
# Train loss 940 0.607144
# Validation loss 940:  0.744642
# Train loss 941 0.598163
# Validation loss 941:  0.731230
# Epoch: 471
# Train loss 942 0.608368
# Validation loss 942:  0.727666
# Train loss 943 0.593221
# Validation loss 943:  0.745794
# Epoch: 472
# Train loss 944 0.605338
# Validation loss 944:  0.728117
# Train loss 945 0.599008
# Validation loss 945:  0.735382
# Epoch: 473
# Train loss 946 0.601321
# Validation loss 946:  0.732279
# Train loss 947 0.592417
# Validation loss 947:  0.722076
# Epoch: 474
# Train loss 948 0.602691
# Validation loss 948:  0.738598
# Train loss 949 0.589695
# Validation loss 949:  0.723701
# Epoch: 475
# Train loss 950 0.594521
# Validation loss 950:  0.725083
# Train loss 951 0.586393
# Validation loss 951:  0.742655
# Epoch: 476
# Train loss 952 0.596054
# Validation loss 952:  0.720029
# Train loss 953 0.578017
# Validation loss 953:  0.722873
# Epoch: 477
# Train loss 954 0.594795
# Validation loss 954:  0.760459
# Train loss 955 0.593407
# Validation loss 955:  0.724832
# Epoch: 478
# Train loss 956 0.583345
# Validation loss 956:  0.731620
# Train loss 957 0.590839
# Validation loss 957:  0.736027
# Epoch: 479
# Train loss 958 0.589381
# Validation loss 958:  0.731206
# Train loss 959 0.571549
# Validation loss 959:  0.737161
# Epoch: 480
# Train loss 960 0.597679
# Validation loss 960:  0.745075
# Train loss 961 0.578344
# Validation loss 961:  0.728967
# Epoch: 481
# Train loss 962 0.582017
# Validation loss 962:  0.727624
# Train loss 963 0.577525
# Validation loss 963:  0.733898
# Epoch: 482
# Train loss 964 0.581509
# Validation loss 964:  0.744601
# Train loss 965 0.578001
# Validation loss 965:  0.717175
# Epoch: 483
# Train loss 966 0.579077
# Validation loss 966:  0.727560
# Train loss 967 0.570791
# Validation loss 967:  0.754305
# Epoch: 484
# Train loss 968 0.591945
# Validation loss 968:  0.724231
# Train loss 969 0.565024
# Validation loss 969:  0.724546
# Epoch: 485
# Train loss 970 0.584206
# Validation loss 970:  0.731058
# Train loss 971 0.569595
# Validation loss 971:  0.721384
# Epoch: 486
# Train loss 972 0.568182
# Validation loss 972:  0.723494
# Train loss 973 0.567299
# Validation loss 973:  0.722242
# Epoch: 487
# Train loss 974 0.568443
# Validation loss 974:  0.736795
# Train loss 975 0.560574
# Validation loss 975:  0.718085
# Epoch: 488
# Train loss 976 0.564876
# Validation loss 976:  0.721771
# Train loss 977 0.554293
# Validation loss 977:  0.744782
# Epoch: 489
# Train loss 978 0.571102
# Validation loss 978:  0.719147
# Train loss 979 0.556395
# Validation loss 979:  0.715551
# Epoch: 490
# Train loss 980 0.562485
# Validation loss 980:  0.724462
# Train loss 981 0.551545
# Validation loss 981:  0.721798
# Epoch: 491
# Train loss 982 0.562904
# Validation loss 982:  0.720850
# Train loss 983 0.545829
# Validation loss 983:  0.717382
# Epoch: 492
# Train loss 984 0.555150
# Validation loss 984:  0.723786
# Train loss 985 0.547299
# Validation loss 985:  0.737224
# Epoch: 493
# Train loss 986 0.557788
# Validation loss 986:  0.718463
# Train loss 987 0.541809
# Validation loss 987:  0.724698
# Epoch: 494
# Train loss 988 0.556258
# Validation loss 988:  0.722440
# Train loss 989 0.542677
# Validation loss 989:  0.717579
# Epoch: 495
# Train loss 990 0.548980
# Validation loss 990:  0.729599
# Train loss 991 0.544382
# Validation loss 991:  0.710808
# Epoch: 496
# Train loss 992 0.548541
# Validation loss 992:  0.714301
# Train loss 993 0.535480
# Validation loss 993:  0.726696
# Epoch: 497
# Train loss 994 0.547184
# Validation loss 994:  0.713704
# Train loss 995 0.541873
# Validation loss 995:  0.727557
# Epoch: 498
# Train loss 996 0.548161
# Validation loss 996:  0.713920
# Train loss 997 0.534762
# Validation loss 997:  0.714802
# Epoch: 499
# Train loss 998 0.548234
# Validation loss 998:  0.738911
# Train loss 999 0.542846
# Validation loss 999:  0.716646
# Epoch: 500
# Train loss 1000 0.545207
# Validation loss 1000:  0.713228
# Train loss 1001 0.527762
# Validation loss 1001:  0.725460
# Epoch: 501
# Train loss 1002 0.546010
# Validation loss 1002:  0.718183
# Train loss 1003 0.530496
# Validation loss 1003:  0.723134
# Epoch: 502
# Train loss 1004 0.538162
# Validation loss 1004:  0.720826
# Train loss 1005 0.526269
# Validation loss 1005:  0.719478
# Epoch: 503
# Train loss 1006 0.533966
# Validation loss 1006:  0.724726
# Train loss 1007 0.522815
# Validation loss 1007:  0.728294
# Epoch: 504
# Train loss 1008 0.532799
# Validation loss 1008:  0.720065
# Train loss 1009 0.528778
# Validation loss 1009:  0.734773
# Epoch: 505
# Train loss 1010 0.532940
# Validation loss 1010:  0.727460
# Train loss 1011 0.522019
# Validation loss 1011:  0.723744
# Epoch: 506
# Train loss 1012 0.539281
# Validation loss 1012:  0.728063
# Train loss 1013 0.524417
# Validation loss 1013:  0.718629
# Epoch: 507
# Train loss 1014 0.525134
# Validation loss 1014:  0.711613
# Train loss 1015 0.520389
# Validation loss 1015:  0.728865
# Epoch: 508
# Train loss 1016 0.529639
# Validation loss 1016:  0.722737
# Train loss 1017 0.519052
# Validation loss 1017:  0.726631
# Epoch: 509
# Train loss 1018 0.520380
# Validation loss 1018:  0.719043
# Train loss 1019 0.512245
# Validation loss 1019:  0.721778
# Epoch: 510
# Train loss 1020 0.530996
# Validation loss 1020:  0.748303
# Train loss 1021 0.525991
# Validation loss 1021:  0.719526
# Epoch: 511
# Train loss 1022 0.523684
# Validation loss 1022:  0.719138
# Train loss 1023 0.510214
# Validation loss 1023:  0.749422
# Epoch: 512
# Train loss 1024 0.534618
# Validation loss 1024:  0.720770
# Train loss 1025 0.516380
# Validation loss 1025:  0.719641
# Epoch: 513
# Train loss 1026 0.518749
# Validation loss 1026:  0.730757
# Train loss 1027 0.510667
# Validation loss 1027:  0.720490
# Epoch: 514
# Train loss 1028 0.519146
# Validation loss 1028:  0.719565
# Train loss 1029 0.509886
# Validation loss 1029:  0.729475
# Epoch: 515
# Train loss 1030 0.521034
# Validation loss 1030:  0.727058
# Train loss 1031 0.503050
# Validation loss 1031:  0.728136
# Epoch: 516
# Train loss 1032 0.513708
# Validation loss 1032:  0.731054
# Train loss 1033 0.510893
# Validation loss 1033:  0.726776
# Epoch: 517
# Train loss 1034 0.515901
# Validation loss 1034:  0.716637
# Train loss 1035 0.499682
# Validation loss 1035:  0.730907
# Epoch: 518
# Train loss 1036 0.514810
# Validation loss 1036:  0.719997
# Train loss 1037 0.507172
# Validation loss 1037:  0.719246
# Epoch: 519
# Train loss 1038 0.510492
# Validation loss 1038:  0.728956
# Train loss 1039 0.501081
# Validation loss 1039:  0.711225
# Epoch: 520
# Train loss 1040 0.510023
# Validation loss 1040:  0.720022
# Train loss 1041 0.498515
# Validation loss 1041:  0.729838
# Epoch: 521
# Train loss 1042 0.504107
# Validation loss 1042:  0.718512
# Train loss 1043 0.491536
# Validation loss 1043:  0.724145
# Epoch: 522
# Train loss 1044 0.505367
# Validation loss 1044:  0.721810

# %% [markdown]
# Finally, this gives you an idea about how to train **Text-to-speech** models and how to monitor the progress and see if the model is learning or not.
